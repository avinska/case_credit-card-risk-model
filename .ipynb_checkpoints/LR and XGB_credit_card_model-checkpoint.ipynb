# %% [markdown]
# <span style="font-size:20pt;font-weight:bold">GOJEK's Code Test - Data Scientist</font>
# <br>
#
# **Author:**
# <br>
# Muhammad Insan Aprilian (insanaprilian50@gmail.com)
# <br>
# <br>
#
# <span style="font-size:16pt;font-weight:bold">Problem Statement</font>
# <br>
#
#
# You are being asked to create a credit scoring model for a lending company. You are given a file with historical data.
# 1.	The upper management wants the overall default rate of their portfolio to be below 2.5%, please provide recommendation on the optimal credit score cutoff rate.
# 2.	Please create a credit score for each individual, validate your solution, and provide guidance on the next steps.
# 3.	Please create deciles by credit score and provide risk and default levels by deciles (by decile and cumulative). Bonus if you can provide confidence (or methodology how you would do it) for your scores/default rates by bin.

# %% [markdown]
# <span style="font-size:16pt;font-weight:bold">The Data Science Workflow</font>
# **<p>1.  Import Packages</p>**
#
# **<p>2.  Import Data</p>**
# <p>&nbsp; &nbsp;     2.1.  Metadata Definition</p>
#
# **<p>3.  Data Exploration</p>**
# <p>&nbsp; &nbsp;     3.1.  Missing Value Check</p>
# <p>&nbsp; &nbsp;     3.2.  Outlier Check (IQR based)</p>
# <p>&nbsp; &nbsp;     3.3.  Predictor Distribution to Target</p>
# <p>&nbsp; &nbsp;     3.4.  Data Split</p>
# <p>&nbsp; &nbsp;     3.5.  Data Transformation</p>
# <p>&nbsp; &nbsp;&nbsp; &nbsp;     3.5.1.  Categorical - Woe Encoder</p>
# <p>&nbsp; &nbsp;&nbsp; &nbsp;     3.5.2.  Numerical - Missing Imputation</p>
# <p>&nbsp; &nbsp;&nbsp; &nbsp;     3.5.3.  Numerical - Standardization</p>
#
# **<p>4.  Predictor Selection</p>**
# <p>&nbsp; &nbsp;     4.1.  Predictor power comparison</p>
# <p>&nbsp; &nbsp;     4.2.  Correlations</p>
#
# **<p>5.  Modeling</p>**
# <p>&nbsp; &nbsp;     5.1.  Logistic Regression Session</p>
# <p>&nbsp; &nbsp;&nbsp; &nbsp;     5.1.1.  Tuning parameter</p>
# <p>&nbsp; &nbsp;&nbsp; &nbsp;     5.1.2.  Train the model</p>
# <p>&nbsp; &nbsp;     5.2.  XGBoost Session</p>
# <p>&nbsp; &nbsp;&nbsp; &nbsp;     5.2.1.  Train initial model</p>
# <p>&nbsp; &nbsp;&nbsp; &nbsp;     5.2.2.  Evaluate predictor</p>
# <p>&nbsp; &nbsp;&nbsp; &nbsp; &nbsp; &nbsp;     5.2.2.1.  Weight of each predictor</p>
# <p>&nbsp; &nbsp;&nbsp; &nbsp; &nbsp; &nbsp;     5.2.2.2.  Gain of each predictor</p>
# <p>&nbsp; &nbsp;&nbsp; &nbsp; &nbsp; &nbsp;     5.2.2.3.  Selected Predictor</p>
# <p>&nbsp; &nbsp;&nbsp; &nbsp;     5.2.3.  Tuning parameter</p>
# <p>&nbsp; &nbsp;&nbsp; &nbsp;     5.2.4.  Final Model</p>
# <p>&nbsp; &nbsp;&nbsp; &nbsp;     5.2.5.  Evaluate final model</p>
# <p>&nbsp; &nbsp;&nbsp; &nbsp; &nbsp; &nbsp;     5.2.5.1.  Gain of each predictor</p>
#
# **<p>6.  Score the dataset</p>**
#
# **<p>7.  Performance characteristics</p>**
# <p>&nbsp; &nbsp;     7.1.  Performance per sample</p>
# <p>&nbsp; &nbsp;     7.2.  ROC Curve</p>
# <p>&nbsp; &nbsp;     7.3.  Score Linearity on Holdout Sample</p>
# <p>&nbsp; &nbsp;     7.4.  Cut-Off Estimation</p>
#
# **<p>8.  Conclusion</p>**

# %% [markdown]
# # Import Packages
#
# - `time` - datetime - ability to get current time for logs
# - `math` - basic mathematical functions (as logarithm etc.))
# - `numpy` - for mathematical,and numerical calculations
# - `scipy` - for metrics evaluation calculations
# - `pandas` - for work with large data structures
# - `scikit` - all important machine learning (and statistical) algorithms used for training the models
# - `matplotlib` - for plotting the charts
# - `seaborn` - for statistical visualisations
# - `xgboost` - gradient boosting used for training the models
# - `category_encoders` - for category type transformation
# - `ia_pkg` - for combined function used in this notebook

# %%
import pandas as pd
import numpy as np
import time
import datetime

import ia_pkg

import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import display, HTML, Markdown

import warnings
warnings.filterwarnings('ignore')

# %%
#Checking used library version
ia_pkg.pkg_version()
# Out:
#  Package version check
# numpy: 1.19.2
# pandas: 1.1.3
# sklearn: 0.23.2
# matplotlib: 3.3.2
# seaborn: 0.11.0
# scipy: 1.5.2
# xgboost: 0.90
# category_encoders : 2.2.2

# %% [markdown]
# # Import Data

# %%
#Import data from CSV
data = pd.read_csv('credit_ds_v3.csv', index_col='X')
print('Data loaded on', datetime.datetime.fromtimestamp(time.time()).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Data loaded on 2020-12-09 21:42:40

# %%
#Running DataFrame optimizer to reduce memory usage
from ia_pkg.function import optimizer
data = optimizer(data)
# Out:
# Memory usage of dataframe is: 2.86 MB
# Memory usage after optimization is: 1.46 MB
# Decreased by 49.0%

# %%
#Remove rows with duplicated index
data=data[~data.index.duplicated(keep='first')]

# %%
print('Number of rows:',data.shape[0])
print('Number of columns:',data.shape[1])
# Out:
# Number of rows: 15645
# Number of columns: 23

# %%
data.head()
# Out:
#    number_of_cards  outstanding  credit_limit       bill  total_cash_usage  \
# X
# 2                2       268691    10000000.0   254564.0               0.0
# 3                3      6769149    28000000.0  4159779.0               0.0
# 5                2      9402085    10000000.0  6099283.0               0.0
# 6                2      6227439    80000000.0  2081248.0               0.0
# 7                2      3906290     4000000.0  2043682.0               0.0
#
#    total_retail_usage  remaining_bill branch_code  payment_ratio  \
# X
# 2              1012.0             0.0           A       0.000000
# 3                 0.0             0.0           A     100.000000
# 5           2666558.0       5951865.0           A      95.989998
# 6           3690250.0       4613435.0           A       0.000000
# 7            230400.0       3314046.0           A      18.469999
#
#    overlimit_percentage  ...  default_flag  years_since_card_issuing  \
# X                        ...
# 2                   0.0  ...             0                  0.750000
# 3                   0.0  ...             0                 10.750000
# 5                   0.0  ...             0                  1.666667
# 6                   0.0  ...             0                 10.250000
# 7                   0.0  ...             0                  4.666667
#
#    total_usage  remaining_bill_per_number_of_cards  remaining_bill_per_limit  \
# X
# 2       1012.0                                 0.0                  0.000000
# 3          0.0                                 0.0                  0.000000
# 5    2666558.0                           2975932.5                  0.595186
# 6    3690250.0                           2306717.5                  0.057668
# 7     230400.0                           1657023.0                  0.828511
#
#    total_usage_per_limit  total_3mo_usage_per_limit  \
# X
# 2               0.000101                   0.000000
# 3               0.000000                   0.040518
# 5               0.266656                   0.323027
# 6               0.046128                   0.017184
# 7               0.057600                   0.018750
#
#    total_6mo_usage_per_limit  utilization_3month  utilization_6month
# X
# 2                   0.000000            0.004232            0.000300
# 3                   0.047703            0.249389                 NaN
# 5                   0.131162            0.707865            0.336571
# 6                   0.117513            0.038964            0.181863
# 7                   0.166667            1.014776            0.977231
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Metadata Definition

# %%
col_target = 'default_flag'

cols_pred = list(data.drop(col_target,axis=1).columns)

cols_pred_num = list(data[cols_pred].select_dtypes(include=np.number).columns)
cols_pred_cat = list(data[cols_pred].select_dtypes(include=np.object).columns)

print('List of numerical predictors:', len(cols_pred_num),'\n\n', data[cols_pred_num].dtypes)
print('\nList of categorical predictors: ', len(cols_pred_cat), '\n\n', data[cols_pred_cat].dtypes)
# Out:
# List of numerical predictors: 21
#
#  number_of_cards                         uint8
# outstanding                            uint32
# credit_limit                          float32
# bill                                  float32
# total_cash_usage                      float32
# total_retail_usage                    float32
# remaining_bill                        float32
# payment_ratio                         float32
# overlimit_percentage                  float32
# payment_ratio_3month                  float32
# payment_ratio_6month                  float32
# delinquency_score                     float32
# years_since_card_issuing              float32
# total_usage                           float32
# remaining_bill_per_number_of_cards    float32
# remaining_bill_per_limit              float32
# total_usage_per_limit                 float32
# total_3mo_usage_per_limit             float32
# total_6mo_usage_per_limit             float32
# utilization_3month                    float32
# utilization_6month                    float32
# dtype: object
#
# List of categorical predictors:  1
#
#  branch_code    object
# dtype: object

# %% [markdown]
# # Data Exploration

# %% [markdown]
# Showing the statistical summary, could help us on preliminary investigation on dataset

# %%
data.describe(include='all').T
# Out:
#                                     count unique  top  freq         mean  \
# number_of_cards                     15645    NaN  NaN   NaN      2.50604
# outstanding                         15645    NaN  NaN   NaN  1.16062e+07
# credit_limit                        15645    NaN  NaN   NaN  2.08205e+07
# bill                                15645    NaN  NaN   NaN  8.07646e+06
# total_cash_usage                    15600    NaN  NaN   NaN      74576.1
# total_retail_usage                  15645    NaN  NaN   NaN  2.02481e+06
# remaining_bill                      15645    NaN  NaN   NaN  8.14679e+06
# branch_code                         15450     11    A  8705          NaN
# payment_ratio                       15645    NaN  NaN   NaN      7.03691
# overlimit_percentage                15619    NaN  NaN   NaN      3.33066
# payment_ratio_3month                15645    NaN  NaN   NaN      50.4964
# payment_ratio_6month                15645    NaN  NaN   NaN      81.5448
# delinquency_score                   15557    NaN  NaN   NaN    0.0337469
# default_flag                        15645    NaN  NaN   NaN    0.0905081
# years_since_card_issuing            15645    NaN  NaN   NaN      6.62887
# total_usage                         15645    NaN  NaN   NaN  2.09928e+06
# remaining_bill_per_number_of_cards  15645    NaN  NaN   NaN  2.97039e+06
# remaining_bill_per_limit            15645    NaN  NaN   NaN     0.467783
# total_usage_per_limit               15645    NaN  NaN   NaN     0.108977
# total_3mo_usage_per_limit           15645    NaN  NaN   NaN     0.167157
# total_6mo_usage_per_limit           15645    NaN  NaN   NaN     0.202453
# utilization_3month                  15645    NaN  NaN   NaN     0.570446
# utilization_6month                  12803    NaN  NaN   NaN     0.526346
#
#                                             std          min         25%  \
# number_of_cards                         1.01254            1           2
# outstanding                         2.40794e+07            0  1.9928e+06
# credit_limit                         2.9555e+07        3e+06       5e+06
# bill                                1.75998e+07        20043      813947
# total_cash_usage                         617732            0           0
# total_retail_usage                  7.90958e+06 -1.56672e+07           0
# remaining_bill                      1.92466e+07            0           0
# branch_code                                 NaN          NaN         NaN
# payment_ratio                           792.892       -49860       -17.3
# overlimit_percentage                    9.21501            0           0
# payment_ratio_3month                     1320.8     -57792.3        20.2
# payment_ratio_6month                    1460.69       -77056        21.5
# delinquency_score                      0.359221            0           0
# default_flag                           0.286918            0           0
# years_since_card_issuing                4.66809         0.75        2.92
# total_usage                         8.07313e+06 -1.56672e+07           0
# remaining_bill_per_number_of_cards  6.27005e+06            0           0
# remaining_bill_per_limit               0.473074            0           0
# total_usage_per_limit                  0.199743       -0.632           0
# total_3mo_usage_per_limit              0.192214       -0.126   0.0347666
# total_6mo_usage_per_limit              0.274423       -0.569      0.0326
# utilization_3month                     0.411998     0.000288       0.189
# utilization_6month                      0.43219            0       0.155
#
#                                             50%          75%          max
# number_of_cards                               2            3           16
# outstanding                         4.71878e+06  1.06653e+07  7.98059e+08
# credit_limit                              9e+06      2.2e+07        1e+09
# bill                                3.14137e+06  7.40407e+06     6.28e+08
# total_cash_usage                              0            0  2.88406e+07
# total_retail_usage                       200000   1.3962e+06     2.85e+08
# remaining_bill                      2.74716e+06  7.14246e+06     4.44e+08
# branch_code                                 NaN          NaN          NaN
# payment_ratio                                 0         44.6        68983
# overlimit_percentage                          0         1.01          190
# payment_ratio_3month                         50         91.2        75575
# payment_ratio_6month                       65.5          100        54899
# delinquency_score                             0            0            5
# default_flag                                  0            0            1
# years_since_card_issuing                5.66667         9.33      34.4167
# total_usage                              243800  1.50748e+06     3.14e+08
# remaining_bill_per_number_of_cards  1.20213e+06  3.08762e+06     1.48e+08
# remaining_bill_per_limit                  0.333        0.929         7.24
# total_usage_per_limit                    0.0217     0.127143          4.6
# total_3mo_usage_per_limit                 0.108        0.239         3.49
# total_6mo_usage_per_limit                 0.117        0.285         8.11
# utilization_3month                        0.574        0.916      8.12567
# utilization_6month                         0.48     0.847594         9.73

# %% [markdown]
# ## Missing Value Check

# %%
# Investigate columns with null values
missingCol = data.isnull().sum()
print("There are", len(missingCol[missingCol != 0]),"columns with missing value")
# Out:
# There are 5 columns with missing value

# %%
# Investigate null rate of contained null columns
missingRate = []
for col in cols_pred:
    if data[col].isnull().any():
        missingRate.append({'Predictor' : col,
                       'Missing rate' : data[col].isnull().sum() / data.shape[0]})
pd.DataFrame(missingRate).set_index('Predictor').sort_values('Missing rate',ascending=False)
# Out:
#                       Missing rate
# Predictor
# utilization_6month        0.181655
# branch_code               0.012464
# delinquency_score         0.005625
# total_cash_usage          0.002876
# overlimit_percentage      0.001662

# %% [markdown]
# ## Outlier Check (IQR based)

# %%
from ia_pkg.function import cnt_outliers, replace_with_thresholds

# Check number of 1.5 IQR based outlier
cnt_outliers(data,cols_pred_num,plot=True)
# Out:
# number_of_cards 's outliers count: 761
# outstanding 's outliers count: 1800
# credit_limit 's outliers count: 2297
# bill 's outliers count: 1828
# total_cash_usage 's outliers count: 736
# total_retail_usage 's outliers count: 2045
# remaining_bill 's outliers count: 1875
# payment_ratio 's outliers count: 500
# overlimit_percentage 's outliers count: 3543
# payment_ratio_3month 's outliers count: 217
# payment_ratio_6month 's outliers count: 261
# delinquency_score 's outliers count: 163
# years_since_card_issuing 's outliers count: 271
# total_usage 's outliers count: 1994
# remaining_bill_per_number_of_cards 's outliers count: 1565
# remaining_bill_per_limit 's outliers count: 11
# total_usage_per_limit 's outliers count: 1665
# total_3mo_usage_per_limit 's outliers count: 763
# total_6mo_usage_per_limit 's outliers count: 815
# utilization_3month 's outliers count: 32
# utilization_6month 's outliers count: 46
# ['number_of_cards',
#  'outstanding',
#  'credit_limit',
#  'bill',
#  'total_cash_usage',
#  'total_retail_usage',
#  'remaining_bill',
#  'payment_ratio',
#  'overlimit_percentage',
#  'payment_ratio_3month',
#  'payment_ratio_6month',
#  'delinquency_score',
#  'years_since_card_issuing',
#  'total_usage',
#  'remaining_bill_per_number_of_cards',
#  'remaining_bill_per_limit',
#  'total_usage_per_limit',
#  'total_3mo_usage_per_limit',
#  'total_6mo_usage_per_limit',
#  'utilization_3month',
#  'utilization_6month']

# %% [markdown]
# Seems all numerical predictor have an outlier, indication that high variability characteristics on the dataset

# %% [markdown]
# ## Predictor Distribution to Target

# %% [markdown]
# **Categorical predictor**

# %%
from ia_pkg.plots import stacked_plot, dist_plot
stacked_plot(data,
            cat_columns=cols_pred_cat,
            col_target=col_target)
# Out:
# ***
# ### branch_code

# %% [markdown]
# From the graph, the *'E'* case on the **branch_code** would riskier than the other value, around 2 times riskier (9% on population to 17%)

# %% [markdown]
# **Numerical Predictor**

# %%
dist_plot(data,
            columns=cols_pred_num,
            col_target=col_target)
# Out:
# ***
# ### number_of_cards
# ***
# ### outstanding
# ***
# ### credit_limit
# ***
# ### bill
# ***
# ### total_cash_usage
# ***
# ### total_retail_usage
# ***
# ### remaining_bill
# ***
# ### payment_ratio
# ***
# ### overlimit_percentage
# ***
# ### payment_ratio_3month
# ***
# ### payment_ratio_6month
# ***
# ### delinquency_score
# ***
# ### years_since_card_issuing
# ***
# ### total_usage
# ***
# ### remaining_bill_per_number_of_cards
# ***
# ### remaining_bill_per_limit
# ***
# ### total_usage_per_limit
# ***
# ### total_3mo_usage_per_limit
# ***
# ### total_6mo_usage_per_limit
# ***
# ### utilization_3month
# ***
# ### utilization_6month

# %% [markdown]
# From the graphs, explicitely there are several predictors that have very good potential on the model. Their ability to differentiate behavior of default and non-default user is used as the base assumption.
#
# Predictor which contained information like **delinquency score**, **Utilization**, **remaining bill** and **overlimit** assumed as the good predictor to the default. But still, further investigation needs to be done (correlation check, etc)

# %% [markdown]
# ## Data Split

# %% [markdown]
# - Split data into three parts (train,valid,test)
# - Adds a new column indicating to which part the observation belong
# - Split is done in random
# - Set the random seed so the results are replicable

# %%
from ia_pkg.function import data_split
data['data_type'] = data_split(data,
                               sample_sizes=[0.8,0.1,0.1],
                               sample_names=['train','test','valid'],
                               seed=42)
# Out:
# train    12516
# valid     1565
# test      1564
# dtype: int64

# %%
#masked the sample name
train_mask = (data['data_type'] == 'train')
valid_mask = (data['data_type'] == 'valid')
test_mask = (data['data_type'] == 'test')

# %%
data_summary = data.groupby(['data_type']).aggregate({col_target:['sum','count']})
data_summary.columns = [col_target, 'rows']
data_summary[col_target+' rate'] = data_summary[col_target] / data_summary['rows']

display(data_summary)
# Out:
#            default_flag   rows  default_flag rate
# data_type
# test              142.0   1564           0.090793
# train            1121.0  12516           0.089565
# valid             153.0   1565           0.097764

# %% [markdown]
# ## Data Transformation

# %% [markdown]
# ### Categorical - Woe Encoder

# %% [markdown]
# WoE method chose to transform the string-type categorical predictor to be in numeric form, WoE estimated the weight of each predictor's unique value for their ability to separate the target(in this case Default/not default).
#
# WoE is also flexible with the null value as we can cluster it into 'special segment'. So the imputation would not be needed in this case.

# %%
from ia_pkg.function import woe_transform
#fit and transform WoE on categorical predictor
data_woe = woe_transform(data,
                         mask=train_mask,
                         cat_columns=cols_pred_cat,
                         col_target=col_target)

# %%
#Stored the WoE output on cols_woe
data_woe.columns = [i + '_woe' for i in data_woe.columns]
cols_woe = list(data_woe.columns)

data[cols_woe] = data_woe

# %%
woe_change = []
#Listed the tranformation result on each unique value on categorical predictor
for col,col_woe in zip(cols_pred_cat,cols_woe):
    woe_change.append(data[[col,col_woe,col_target]].fillna('Null').groupby([col,col_woe]).agg(
        {col_woe: ['count'],
         col_target : ['sum','mean']}))

for i in range(len(woe_change)):
    woe_change[i]
woe_change[0].columns = [('branch_code_woe count'),
            (   'default_flag count'),
            (   'default_flag rate')]
pd.DataFrame(woe_change[0])
# Out:
#                              branch_code_woe count  default_flag count  \
# branch_code branch_code_woe
# A           -0.031288                         8705               767.0
# B            0.058419                         1351               132.0
# C           -0.092869                          334                27.0
# D           -0.353662                          205                12.0
# E            0.793162                          649               114.0
# F           -0.045147                         1697               144.0
# G           -0.619890                          566                30.0
# H            0.144728                          367                33.0
# I            0.131295                          991               102.0
# J           -0.070761                          410                33.0
# K            0.112217                          175                17.0
# Null        -1.320240                          195                 5.0
#
#                              default_flag rate
# branch_code branch_code_woe
# A           -0.031288                 0.088110
# B            0.058419                 0.097705
# C           -0.092869                 0.080838
# D           -0.353662                 0.058537
# E            0.793162                 0.175655
# F           -0.045147                 0.084856
# G           -0.619890                 0.053004
# H            0.144728                 0.089918
# I            0.131295                 0.102926
# J           -0.070761                 0.080488
# K            0.112217                 0.097143
# Null        -1.320240                 0.025641

# %% [markdown]
# ### Numerical - Missing Imputation

# %% [markdown]
# Missing value imputation is done by filling the mean value to each predictor

# %%
cols_num_missing = data[cols_pred_num].columns[data[cols_pred_num].isnull().any()].tolist()
#filling the missing value with mean
for c in cols_num_missing:
    mean = data[c].mean()
    data[c+'_imp'] = data[c].fillna(mean,axis=0)

# %% [markdown]
# ### Numerical - Standardization

# %% [markdown]
# Scaling is done on numerical predictors to avoid the outlier/bigger magnitude value effects on the model. Standardization is one of the methods for scaling, it transformed all the values by centering its mean at 0 then scales the variance at 1.
#
# The pros of this method is it keeping the shape of the predictor's original distribution

# %%
from sklearn.preprocessing import StandardScaler
#listed the imputation and non-imputation predictor for scaling
cols_pred_num2 = list(map(lambda x: x+'_imp' if x in cols_num_missing else x, cols_pred_num))       

scaler = StandardScaler(with_mean=True, with_std=True)
scaler.fit(data[train_mask][cols_pred_num2])
# print(scaler.mean_)
data_sd = scaler.transform(data[train_mask|valid_mask|test_mask][cols_pred_num2])

# %%
# stored the standardscaler output on cols_sd
cols_sd = [i+'_sd' for i in cols_pred_num]

data[cols_sd] = data_sd
data[cols_sd].head()
# Out:
#    number_of_cards_sd  outstanding_sd  credit_limit_sd   bill_sd  \
# X
# 2           -0.496018       -0.465729        -0.370874 -0.433910
# 3            0.479648       -0.197352         0.251065 -0.218449
# 5           -0.496018       -0.088649        -0.370874 -0.111441
# 6           -0.496018       -0.219717         2.047777 -0.333127
# 7           -0.496018       -0.315548        -0.578187 -0.335200
#
#    total_cash_usage_sd  total_retail_usage_sd  remaining_bill_sd  \
# X
# 2            -0.116031              -0.249690          -0.412474
# 3            -0.116031              -0.249815          -0.412474
# 5            -0.116031               0.079252          -0.112516
# 6            -0.116031               0.205580          -0.179969
# 7            -0.116031              -0.221383          -0.245455
#
#    payment_ratio_sd  overlimit_percentage_sd  payment_ratio_3month_sd  ...  \
# X                                                                      ...
# 2         -0.012909                -0.358145                -0.042164  ...
# 3          0.119361                -0.358145                 0.033772  ...
# 5          0.114057                -0.358145                 0.031866  ...
# 6         -0.012909                -0.358145                -0.020552  ...
# 7          0.011521                -0.358145                -0.023218  ...
#
#    delinquency_score_sd  years_since_card_issuing_sd  total_usage_sd  \
# X
# 2              0.000003                    -1.260136       -0.252671
# 3              0.000003                     0.883030       -0.252793
# 5              0.000003                    -1.063679        0.068673
# 6              0.000003                     0.775872        0.192085
# 7              0.000003                    -0.420729       -0.225018
#
#    remaining_bill_per_number_of_cards_sd  remaining_bill_per_limit_sd  \
# X
# 2                              -0.471298                    -0.985386
# 3                              -0.471298                    -0.985386
# 5                               0.001933                     0.265374
# 6                              -0.104485                    -0.864199
# 7                              -0.207799                     0.755697
#
#    total_usage_per_limit_sd  total_3mo_usage_per_limit_sd  \
# X
# 2                 -0.538068                     -0.869207
# 3                 -0.538569                     -0.659253
# 5                  0.781630                      0.804642
# 6                 -0.310191                     -0.780162
# 7                 -0.253395                     -0.772049
#
#    total_6mo_usage_per_limit_sd  utilization_3month_sd  utilization_6month_sd
# X
# 2                     -0.726734              -1.383978              -1.346817
# 3                     -0.555666              -0.785162              -0.003964
# 5                     -0.256373               0.334700              -0.488407
# 6                     -0.305321              -1.299142              -0.883334
# 7                     -0.129052               1.084353               1.147024
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Wrapped up all the transformed predictor

# %%
cols_shortlist = []

for c in cols_sd:
    cols_shortlist.append(c)
for c in cols_woe:
    cols_shortlist.append(c)

display(cols_shortlist)
# Out:
# ['number_of_cards_sd',
#  'outstanding_sd',
#  'credit_limit_sd',
#  'bill_sd',
#  'total_cash_usage_sd',
#  'total_retail_usage_sd',
#  'remaining_bill_sd',
#  'payment_ratio_sd',
#  'overlimit_percentage_sd',
#  'payment_ratio_3month_sd',
#  'payment_ratio_6month_sd',
#  'delinquency_score_sd',
#  'years_since_card_issuing_sd',
#  'total_usage_sd',
#  'remaining_bill_per_number_of_cards_sd',
#  'remaining_bill_per_limit_sd',
#  'total_usage_per_limit_sd',
#  'total_3mo_usage_per_limit_sd',
#  'total_6mo_usage_per_limit_sd',
#  'utilization_3month_sd',
#  'utilization_6month_sd',
#  'branch_code_woe']

# %% [markdown]
# # Predictor Selection
# <br>
#
# Selecting the best predictor for the model, it applied to all transformed predictors. The selection metrics would be **gini, IV** (Predictive power), and **inter-predictor correlation**

# %% [markdown]
# ## Predictive power comparison
#
# Calculates IV and Gini of each predictor, sorts the predictors by their power. The power is calculated for each of the samples (train, validate, test).

# %%
from ia_pkg.metrics import iv,gini

power_tab = []
for j in range(0,len(cols_shortlist)):
    power_tab.append({'Name':cols_shortlist[j]
                    ,'Gini Train':gini(data.loc[train_mask,col_target],data.loc[train_mask,cols_shortlist[j]])                    
                    ,'Gini Validate':gini(data.loc[valid_mask,col_target],data.loc[valid_mask,cols_shortlist[j]])
                    ,'Gini Test':gini(data.loc[test_mask,col_target],data.loc[test_mask,cols_shortlist[j]])
                    ,'IV Train':iv(data.loc[train_mask,col_target],data.loc[train_mask,cols_shortlist[j]])
                    ,'IV Validate':iv(data.loc[valid_mask,col_target],data.loc[valid_mask,cols_shortlist[j]])
                    ,'IV Test':iv(data.loc[test_mask,col_target],data.loc[test_mask,cols_shortlist[j]])     
                     })
power_out = pd.DataFrame.from_records(power_tab)
power_out = power_out.set_index('Name').abs()
power_out = power_out.sort_values('Gini Validate',ascending=False)

pd.options.display.max_rows = 1000
display(power_out)
pd.options.display.max_rows = 30
# Out:
#                                        Gini Train  Gini Validate  Gini Test  \
# Name
# payment_ratio_3month_sd                  0.443390       0.531032   0.390122
# total_retail_usage_sd                    0.437361       0.497010   0.437536
# total_usage_per_limit_sd                 0.425662       0.488821   0.413542
# total_usage_sd                           0.423991       0.483910   0.397907
# payment_ratio_6month_sd                  0.283779       0.405497   0.243507
# total_3mo_usage_per_limit_sd             0.244155       0.324974   0.185070
# remaining_bill_per_limit_sd              0.249066       0.278185   0.290753
# remaining_bill_sd                        0.201198       0.266669   0.231632
# remaining_bill_per_number_of_cards_sd    0.202280       0.250481   0.234979
# overlimit_percentage_sd                  0.245677       0.206378   0.323726
# utilization_3month_sd                    0.160570       0.176040   0.160773
# payment_ratio_sd                         0.068997       0.167523   0.026911
# utilization_6month_sd                    0.135191       0.133232   0.103390
# branch_code_woe                          0.095017       0.127349   0.049642
# total_6mo_usage_per_limit_sd             0.087867       0.101960   0.004016
# delinquency_score_sd                     0.089921       0.085713   0.082595
# bill_sd                                  0.070470       0.079158   0.139082
# number_of_cards_sd                       0.020666       0.075538   0.038118
# years_since_card_issuing_sd              0.022144       0.049992   0.056189
# outstanding_sd                           0.009293       0.041211   0.061072
# total_cash_usage_sd                      0.031882       0.018951   0.023033
# credit_limit_sd                          0.022590       0.012415   0.025772
#
#                                         IV Train  IV Validate    IV Test
# Name
# payment_ratio_3month_sd                 3.587264     8.306060   9.442355
# total_retail_usage_sd                   6.131127     8.580574   9.130802
# total_usage_per_limit_sd                3.911063     7.414744   8.336337
# total_usage_sd                          6.430831     8.777443   9.428548
# payment_ratio_6month_sd                 3.177101     7.299208   8.067143
# total_3mo_usage_per_limit_sd            4.759086     9.485955  10.666933
# remaining_bill_per_limit_sd             4.180819     7.796339   8.301508
# remaining_bill_sd                       9.280871    11.615734  12.621391
# remaining_bill_per_number_of_cards_sd  11.099938    11.908745  13.173565
# overlimit_percentage_sd                 2.207497     4.336240   4.783667
# utilization_3month_sd                   4.984841     9.800172  11.314344
# payment_ratio_sd                        3.039068     5.213683   6.053063
# utilization_6month_sd                   4.060876     8.652189   9.550559
# branch_code_woe                         0.064035     0.092045   0.040409
# total_6mo_usage_per_limit_sd            4.721092     9.478506  10.453081
# delinquency_score_sd                    0.513499     0.443645   0.435592
# bill_sd                                12.530846    15.483196  17.411929
# number_of_cards_sd                      0.019503     0.109915   0.058556
# years_since_card_issuing_sd             0.659121     2.408678   2.595064
# outstanding_sd                         12.940145    15.762832  17.511422
# total_cash_usage_sd                     0.322946     0.428282   0.544924
# credit_limit_sd                         0.195625     0.903445   0.979014

# %% [markdown]
# ## Correlations

# %% [markdown]
# Show correlation matrix of all predictor

# %%
cormat = data[sorted(cols_shortlist)].corr()

plt.rcParams.update({'font.size': 15})
sns.set()
# %matplotlib inline
# %config InlineBackend.close_figures=True

fig, ax = plt.subplots(figsize=(12,10), dpi=50)
fig.suptitle('Correlations of Variables',fontsize=25)
sns.heatmap(cormat, ax=ax, annot=True, fmt="0.1f", linewidths=.5, annot_kws={"size":15},cmap="OrRd")
plt.tick_params(labelsize=15)
plt.xticks(rotation=90)
plt.yticks(rotation=0)

plt.show()
plt.clf();plt.close()

# %%
max_ok_correlation = 0.5

# find highest pairwise correlation (correlation greater than .. in absolute value)
hicors = []
for i in range(0,len(cormat)):
    for j in range(0,len(cormat)):
        if ((cormat.iloc[i][j] > max_ok_correlation or cormat.iloc[i][j] < -max_ok_correlation) and i < j):
            hicors.append((i,j,cormat.index[i],cormat.index[j],cormat.iloc[i][j],abs(cormat.iloc[i][j])))
hicors.sort(key= lambda x: x[5], reverse=True)

hicors2 = pd.DataFrame(list(zip(*list(zip(*hicors))[2:5])), columns = ['predictor_1', 'predictor_2', 'corr'])

# print list of highest correlations
hicors2
# Out:
#                               predictor_1  \
# 0                   total_retail_usage_sd
# 1   remaining_bill_per_number_of_cards_sd
# 2                                 bill_sd
# 3                                 bill_sd
# 4                          outstanding_sd
# 5             remaining_bill_per_limit_sd
# 6                   utilization_3month_sd
# 7                                 bill_sd
# 8                          outstanding_sd
# 9                         credit_limit_sd
# 10           total_3mo_usage_per_limit_sd
# 11                                bill_sd
# 12            remaining_bill_per_limit_sd
# 13                         outstanding_sd
# 14                         outstanding_sd
# 15                overlimit_percentage_sd
# 16                        credit_limit_sd
# 17                overlimit_percentage_sd
#
#                               predictor_2      corr
# 0                          total_usage_sd  0.997217
# 1                       remaining_bill_sd  0.913902
# 2                          outstanding_sd  0.871068
# 3                       remaining_bill_sd  0.832762
# 4                       remaining_bill_sd  0.811607
# 5                   utilization_3month_sd  0.783759
# 6                   utilization_6month_sd  0.750076
# 7   remaining_bill_per_number_of_cards_sd  0.738752
# 8   remaining_bill_per_number_of_cards_sd  0.712734
# 9                          outstanding_sd  0.707317
# 10           total_6mo_usage_per_limit_sd  0.629144
# 11                        credit_limit_sd  0.617095
# 12                  utilization_6month_sd  0.543948
# 13                         total_usage_sd  0.543237
# 14                  total_retail_usage_sd  0.535768
# 15                  utilization_3month_sd  0.508715
# 16                      remaining_bill_sd  0.507696
# 17            remaining_bill_per_limit_sd  0.503784

# %% [markdown]
# Combining output set from these selection methods, we choosing the predictor which placed on top individual predictive power and eliminate which both ranked on bottom(low gini) and having inter-predictor correlation (>0.5)
#
#
# This new predictor set expected can prevent the low quality and mulitcollinearity issue that may occur on the model(e.g. Logistic Regression)

# %% [markdown]
# # Modeling

# %% [markdown]
# Modeling using two methods (CV Logistic Regression and XGBoost) on training data set. We take a different set of predictors for each model.
#
# For Logistic Regression, we take transformed(*WoE* and *Imputation-Standardization*) and selected(*individual gini* and *correlation-based*) predictor called **pred_lr**
#
# For XGBoost, we take transformed WoE and non-transformed numerical predictors (leave it as it is), XGBoost decision-tree is robust on outlier and null values so we confidently don't use numerical transformation on this. The set called **pred_xgb**

# %% [markdown]
# ## Logistic Regression Session

# %% [markdown]
# Selected predictor for Logistic Regression

# %%
cols_shortlist2 = ['number_of_cards_sd',
#  'outstanding_sd',
 'credit_limit_sd',
#  'bill_sd',
#  'total_cash_usage_sd',
 'total_retail_usage_sd',
#  'remaining_bill_sd',
 'payment_ratio_sd',
#  'overlimit_percentage_sd',
 'payment_ratio_3month_sd',
 'payment_ratio_6month_sd',
 'delinquency_score_sd',
#  'years_since_card_issuing_sd',
#  'total_usage_sd',
#  'remaining_bill_per_number_of_cards_sd',
 'remaining_bill_per_limit_sd',
 'total_usage_per_limit_sd',
 'total_3mo_usage_per_limit_sd',
#  'total_6mo_usage_per_limit_sd',
#  'utilization_3month_sd',
#  'utilization_6month_sd',
 'branch_code_woe']

# %%
pred_lr = cols_shortlist2

# %% [markdown]
# ### Tuning parameter

# %% [markdown]
# Tuning is done to know which regularization parameter (C) would be the best to estimate the model, estimated by his ability to balance the bias-variance

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
#Grid Search
logreg = LogisticRegression(class_weight='balanced',penalty='l2')

param = {'C':[0.001,0.005,0.01,0.05,0.1,0.5,1,5,10,50,100,500,1000,5000,10000]}
gs = GridSearchCV(logreg,param,scoring='roc_auc',refit=True,cv=5)
gs.fit(data[train_mask|valid_mask][pred_lr],data[train_mask|valid_mask][col_target])
print('Best roc_auc: {:.4}, with best C: {}'.format(gs.best_score_, gs.best_params_))
# Out:
# Best roc_auc: 0.7484, with best C: {'C': 1000}

# %% [markdown]
# ### Train the model

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression(C=gs.best_params_.get('C'))

gs = GridSearchCV(logreg,param,refit=True,cv=5)
gs.fit(data[train_mask|valid_mask][pred_lr],data[train_mask|valid_mask][col_target])
# logreg.fit(data[train_mask|valid_mask][pred_lr],data[train_mask|valid_mask][col_target])

lr_scored = gs.predict_proba(data[pred_lr])[:,1]

# %% [markdown]
# Plotted the model's Coefficient and Intercept

# %%
o = []
o.append('|LR MODEL | COEFFICIENTS |\n| --- | --- |')
o.append('| Intercept: | {} |'.format(gs.best_estimator_.intercept_[0]))
for p,b in zip(pred_lr,list(gs.best_estimator_.coef_[0])):
    o.append('| {} | {} |'.format(p,b))
display(Markdown('\n'.join(o)))
# Out:
# |LR MODEL | COEFFICIENTS |
# | --- | --- |
# | Intercept: | -2.7252430255806996 |
# | number_of_cards_sd | 0.03200591510553616 |
# | credit_limit_sd | 0.10749052568948028 |
# | total_retail_usage_sd | 0.024460559134403162 |
# | payment_ratio_sd | -0.009714549581618555 |
# | payment_ratio_3month_sd | -0.005565329197342669 |
# | payment_ratio_6month_sd | -0.006455658866908326 |
# | delinquency_score_sd | 0.6758076606017338 |
# | remaining_bill_per_limit_sd | 0.5531621468787854 |
# | total_usage_per_limit_sd | -0.9772492206697043 |
# | total_3mo_usage_per_limit_sd | -0.26918477813116726 |
# | branch_code_woe | 0.5334794567364938 |

# %% [markdown]
# Coefficient magnitude could tell us the predictor contribution to the model,
#
# since we scaling them with the same method, we could say that **delinquency score** *(B=.676)* and **total_usage_per_limit** *(B=-.977)* are the biggest contributorsto the model. **delinquency_score** has a positive and **total_usage_per_limit** has a negative relationship to the defaults

# %% [markdown]
# ## XGBoost Session

# %% [markdown]
# Needs xgboost library to be installed.
#
# First we train a gradient boosting model using a "standard" set of hyperparameters.

# %%
pred_xgb = cols_pred_num + [c + '_woe' for c in cols_pred_cat]

# %% [markdown]
# ### Train initial model

# %%
from ia_pkg.metrics import gini
import xgboost as xgb
# pred_xgb.remove('delinquency_score')
dt_xgb = data[pred_xgb]

xgb_params = {'eta': 0.1,
  'max_depth': 3,
  'objective': 'binary:logistic',
  'eval_metric': 'auc',
  'min_child_weight': 30,
  'subsample': 0.85}

evals_result = {}

ibooster= xgb.train(params= xgb_params,
                        dtrain= xgb.DMatrix(dt_xgb[train_mask],data[train_mask][col_target]),
                        num_boost_round= 200,
                        early_stopping_rounds = 20,
                        evals= ((xgb.DMatrix(dt_xgb[train_mask],data[train_mask][col_target]),'train'),
                                 (xgb.DMatrix(dt_xgb[valid_mask],data[valid_mask][col_target]),'valid')
                                ), 
                        evals_result= evals_result,)

ixgb_scored= ibooster.predict(xgb.DMatrix(dt_xgb), ntree_limit=ibooster.best_ntree_limit)
# Out:
# [0]	train-auc:0.790334	valid-auc:0.786061
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.82107	valid-auc:0.804197
# [2]	train-auc:0.820511	valid-auc:0.80955
# [3]	train-auc:0.83342	valid-auc:0.821569
# [4]	train-auc:0.844397	valid-auc:0.832979
# [5]	train-auc:0.846528	valid-auc:0.840705
# [6]	train-auc:0.847349	valid-auc:0.84395
# [7]	train-auc:0.849728	valid-auc:0.845882
# [8]	train-auc:0.851346	valid-auc:0.845581
# [9]	train-auc:0.851232	valid-auc:0.846044
# [10]	train-auc:0.851928	valid-auc:0.84843
# [11]	train-auc:0.852506	valid-auc:0.84943
# [12]	train-auc:0.857256	valid-auc:0.850823
# [13]	train-auc:0.859862	valid-auc:0.852027
# [14]	train-auc:0.861601	valid-auc:0.852041
# [15]	train-auc:0.861933	valid-auc:0.851779
# [16]	train-auc:0.861969	valid-auc:0.850821
# [17]	train-auc:0.863597	valid-auc:0.852888
# [18]	train-auc:0.864507	valid-auc:0.85433
# [19]	train-auc:0.86574	valid-auc:0.855908
# [20]	train-auc:0.865995	valid-auc:0.856735
# [21]	train-auc:0.866645	valid-auc:0.857288
# [22]	train-auc:0.866822	valid-auc:0.856741
# [23]	train-auc:0.867352	valid-auc:0.857561
# [24]	train-auc:0.867759	valid-auc:0.857866
# [25]	train-auc:0.867971	valid-auc:0.858426
# [26]	train-auc:0.868333	valid-auc:0.859047
# [27]	train-auc:0.868734	valid-auc:0.859088
# [28]	train-auc:0.869839	valid-auc:0.859801
# [29]	train-auc:0.870718	valid-auc:0.85981
# [30]	train-auc:0.871199	valid-auc:0.859639
# [31]	train-auc:0.871584	valid-auc:0.860287
# [32]	train-auc:0.87259	valid-auc:0.860912
# [33]	train-auc:0.872815	valid-auc:0.861636
# [34]	train-auc:0.873211	valid-auc:0.86259
# [35]	train-auc:0.873963	valid-auc:0.862803
# [36]	train-auc:0.874577	valid-auc:0.863326
# [37]	train-auc:0.875204	valid-auc:0.86446
# [38]	train-auc:0.876171	valid-auc:0.865078
# [39]	train-auc:0.876498	valid-auc:0.865184
# [40]	train-auc:0.8771	valid-auc:0.865499
# [41]	train-auc:0.877612	valid-auc:0.865976
# [42]	train-auc:0.877694	valid-auc:0.86586
# [43]	train-auc:0.87818	valid-auc:0.866402
# [44]	train-auc:0.878597	valid-auc:0.866427
# [45]	train-auc:0.879125	valid-auc:0.867094
# [46]	train-auc:0.879601	valid-auc:0.868221
# [47]	train-auc:0.879856	valid-auc:0.868624
# [48]	train-auc:0.880243	valid-auc:0.869008
# [49]	train-auc:0.880766	valid-auc:0.869675
# [50]	train-auc:0.881304	valid-auc:0.869401
# [51]	train-auc:0.881723	valid-auc:0.870142
# [52]	train-auc:0.882174	valid-auc:0.869462
# [53]	train-auc:0.882174	valid-auc:0.869837
# [54]	train-auc:0.882443	valid-auc:0.870739
# [55]	train-auc:0.882695	valid-auc:0.871026
# [56]	train-auc:0.88302	valid-auc:0.872107
# [57]	train-auc:0.883304	valid-auc:0.872255
# [58]	train-auc:0.883572	valid-auc:0.872445
# [59]	train-auc:0.883932	valid-auc:0.872547
# [60]	train-auc:0.884449	valid-auc:0.872963
# [61]	train-auc:0.884541	valid-auc:0.873093
# [62]	train-auc:0.884744	valid-auc:0.873486
# [63]	train-auc:0.885013	valid-auc:0.873227
# [64]	train-auc:0.88554	valid-auc:0.873734
# [65]	train-auc:0.885913	valid-auc:0.874239
# [66]	train-auc:0.886064	valid-auc:0.874169
# [67]	train-auc:0.88621	valid-auc:0.874447
# [68]	train-auc:0.886321	valid-auc:0.874391
# [69]	train-auc:0.886423	valid-auc:0.874396
# [70]	train-auc:0.886593	valid-auc:0.875053
# [71]	train-auc:0.88708	valid-auc:0.875039
# [72]	train-auc:0.887441	valid-auc:0.874725
# [73]	train-auc:0.887389	valid-auc:0.874637
# [74]	train-auc:0.887713	valid-auc:0.874289
# [75]	train-auc:0.888155	valid-auc:0.874484
# [76]	train-auc:0.88837	valid-auc:0.874285
# [77]	train-auc:0.888694	valid-auc:0.874789
# [78]	train-auc:0.888822	valid-auc:0.874993
# [79]	train-auc:0.888979	valid-auc:0.87528
# [80]	train-auc:0.889228	valid-auc:0.874799
# [81]	train-auc:0.889415	valid-auc:0.874428
# [82]	train-auc:0.889695	valid-auc:0.87447
# [83]	train-auc:0.889765	valid-auc:0.874586
# [84]	train-auc:0.890052	valid-auc:0.874604
# [85]	train-auc:0.890213	valid-auc:0.874382
# [86]	train-auc:0.890425	valid-auc:0.874586
# [87]	train-auc:0.890658	valid-auc:0.874489
# [88]	train-auc:0.891068	valid-auc:0.874532
# [89]	train-auc:0.891459	valid-auc:0.87441
# [90]	train-auc:0.891637	valid-auc:0.874183
# [91]	train-auc:0.891686	valid-auc:0.8741
# [92]	train-auc:0.891831	valid-auc:0.87466
# [93]	train-auc:0.891934	valid-auc:0.874706
# [94]	train-auc:0.892025	valid-auc:0.874692
# [95]	train-auc:0.892224	valid-auc:0.874419
# [96]	train-auc:0.892411	valid-auc:0.874345
# [97]	train-auc:0.892525	valid-auc:0.874114
# [98]	train-auc:0.892809	valid-auc:0.874063
# [99]	train-auc:0.893117	valid-auc:0.874289
# Stopping. Best iteration:
# [79]	train-auc:0.888979	valid-auc:0.87528

# %%
print('     Train gini:',gini(data[train_mask][col_target], ixgb_scored[train_mask]))
print('Validation gini:',gini(data[valid_mask][col_target], ixgb_scored[valid_mask]))
# Out:
#      Train gini: 0.7779580774546642
# Validation gini: 0.7505600918365458

# %% [markdown]
# ### Evaluate predictor

# %% [markdown]
# Predictors evaluated due to their sorted importances on two metrics (weight and gain). At first, we can set the number of predictors which we want to see

# %%
n_top = 10 #how many best predictors I want to see

# %% [markdown]
# #### Weight of each predictor

# %% [markdown]
# Select *n_top* predictors with highest weight (i.e. those which were in most trees)

# %%
pred_xgb_wgh = [x[0] for x in sorted([(k, v) for k, v in ibooster.get_score(importance_type = 'weight').items()]\
                                     , key=lambda x:x[1], reverse = True)]
if len(pred_xgb_wgh) > n_top:
    pred_xgb_wgh = pred_xgb_wgh[:n_top]

# %% [markdown]
# #### Gain of each predictor

# %% [markdown]
# Select *n_top* predictors with highest gain (i.e. relative contribution of the corresponding feature to the model calculated by taking each feature’s contribution for each tree in the model)

# %%
pred_xgb_gain = [x[0] for x in sorted([(k, v) for k, v in ibooster.get_score(importance_type = 'gain').items()]\
                                      , key=lambda x:x[1], reverse = True)]
if len(pred_xgb_gain) > n_top:
    pred_xgb_gain = pred_xgb_gain[:n_top]

# %% [markdown]
# #### Selected Predictor

# %% [markdown]
# Select the final predictors as we combining (union or intersection) the output from each metrics

# %%
def union(lst1, lst2):
    final_list  = list(set(lst1) | set(lst2))
    return final_list

def intersect(lst1, lst2):
    final_list = list(set(lst1) & set(lst2))
    return final_list

# %%
pred_xgb = union(pred_xgb_wgh, pred_xgb_gain)
display(pred_xgb)
# Out:
# ['delinquency_score',
#  'utilization_3month',
#  'years_since_card_issuing',
#  'total_3mo_usage_per_limit',
#  'total_usage',
#  'payment_ratio',
#  'payment_ratio_6month',
#  'outstanding',
#  'total_retail_usage',
#  'payment_ratio_3month',
#  'bill',
#  'total_usage_per_limit',
#  'overlimit_percentage']

# %% [markdown]
# ### Tuning parameter

# %% [markdown]
# Hyperparameter tuning applied to two inputs (max_depth and learning rate).
# Tuning set then will be evaluated on the valid sample.
#
# There are two options on the best estimation to choose from.
#
# *best_valid* for tuning set that has best gini on valid sample
#
# *best_diff* for tuning set that has train-valid lowest gini difference

# %%
from ia_pkg.metrics import gini

import xgboost as xgb

dt_xgb = data[pred_xgb]

col_result = ['eta', 'max_depth', 'gini_train', 'gini_valid', 'difference']
result = pd.DataFrame(columns = col_result)
grid_params = {
            'eta' : [0.1,0.2,0.3],
            'max_depth' : [2,3,4]
#               'min_child_weight' : [10,20,30,40,50],
#               'subsample' : [0.5, 0.6, 0.7, 0.8, 0.9]      
}

flag = False

for eta in grid_params['eta']:
    for max_depth in grid_params['max_depth']:
        xgb_params = {'eta': eta,
                            'max_depth': max_depth,
                            'objective': 'binary:logistic',
                            'eval_metric': 'auc',
                            'min_child_weight': 30,
                            'subsample': 0.85}

        evals_result = {}

        tbooster = xgb.train(params = xgb_params,
                                    dtrain = xgb.DMatrix(dt_xgb[train_mask],data[train_mask][col_target]),
                                    num_boost_round = 200,
                                    early_stopping_rounds = 20,
                                    evals = ((xgb.DMatrix(dt_xgb[train_mask],data[train_mask][col_target]),'train'),
                                             (xgb.DMatrix(dt_xgb[valid_mask],data[valid_mask][col_target]),'valid')
                                            ), 
                                    evals_result = evals_result,)

        txgb_scored = tbooster.predict(xgb.DMatrix(dt_xgb), ntree_limit=tbooster.best_ntree_limit)
        gini_train = gini(data[train_mask][col_target], txgb_scored[train_mask])
        gini_valid = gini(data[valid_mask][col_target], txgb_scored[valid_mask])
        added = [eta, max_depth, gini_train, gini_valid, (gini_train-gini_valid)]
        if flag == False:
            result = pd.DataFrame([added], columns = col_result)
            flag = True
        else:
            result = pd.concat([result, pd.DataFrame([added], columns = col_result)], axis=0)
# Out:
# [0]	train-auc:0.755108	valid-auc:0.762223
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.79242	valid-auc:0.796664
# [2]	train-auc:0.793945	valid-auc:0.7982
# [3]	train-auc:0.808859	valid-auc:0.806602
# [4]	train-auc:0.807372	valid-auc:0.806905
# [5]	train-auc:0.819533	valid-auc:0.821472
# [6]	train-auc:0.825141	valid-auc:0.828387
# [7]	train-auc:0.828222	valid-auc:0.828276
# [8]	train-auc:0.827415	valid-auc:0.827934
# [9]	train-auc:0.827064	valid-auc:0.828279
# [10]	train-auc:0.830463	valid-auc:0.835463
# [11]	train-auc:0.831571	valid-auc:0.834509
# [12]	train-auc:0.835062	valid-auc:0.838962
# [13]	train-auc:0.837909	valid-auc:0.842991
# [14]	train-auc:0.83857	valid-auc:0.844165
# [15]	train-auc:0.838603	valid-auc:0.844507
# [16]	train-auc:0.83846	valid-auc:0.844605
# [17]	train-auc:0.844205	valid-auc:0.849979
# [18]	train-auc:0.844244	valid-auc:0.851962
# [19]	train-auc:0.846942	valid-auc:0.854147
# [20]	train-auc:0.846321	valid-auc:0.853934
# [21]	train-auc:0.848338	valid-auc:0.856003
# [22]	train-auc:0.850775	valid-auc:0.856836
# [23]	train-auc:0.851327	valid-auc:0.856235
# [24]	train-auc:0.852245	valid-auc:0.856413
# [25]	train-auc:0.851975	valid-auc:0.855635
# [26]	train-auc:0.852824	valid-auc:0.856735
# [27]	train-auc:0.854702	valid-auc:0.858299
# [28]	train-auc:0.856925	valid-auc:0.859716
# [29]	train-auc:0.857284	valid-auc:0.861294
# [30]	train-auc:0.857653	valid-auc:0.861674
# [31]	train-auc:0.858088	valid-auc:0.862882
# [32]	train-auc:0.858075	valid-auc:0.863787
# [33]	train-auc:0.859374	valid-auc:0.863134
# [34]	train-auc:0.860604	valid-auc:0.863567
# [35]	train-auc:0.860703	valid-auc:0.863321
# [36]	train-auc:0.861539	valid-auc:0.862916
# [37]	train-auc:0.862594	valid-auc:0.86381
# [38]	train-auc:0.863772	valid-auc:0.864483
# [39]	train-auc:0.864334	valid-auc:0.864988
# [40]	train-auc:0.864778	valid-auc:0.864571
# [41]	train-auc:0.864755	valid-auc:0.864363
# [42]	train-auc:0.865486	valid-auc:0.863127
# [43]	train-auc:0.866137	valid-auc:0.863581
# [44]	train-auc:0.86674	valid-auc:0.862921
# [45]	train-auc:0.867229	valid-auc:0.865048
# [46]	train-auc:0.867452	valid-auc:0.866001
# [47]	train-auc:0.867757	valid-auc:0.866983
# [48]	train-auc:0.868714	valid-auc:0.86773
# [49]	train-auc:0.869017	valid-auc:0.868038
# [50]	train-auc:0.869637	valid-auc:0.86789
# [51]	train-auc:0.870011	valid-auc:0.86783
# [52]	train-auc:0.870346	valid-auc:0.867596
# [53]	train-auc:0.870181	valid-auc:0.868006
# [54]	train-auc:0.870118	valid-auc:0.867987
# [55]	train-auc:0.870362	valid-auc:0.867909
# [56]	train-auc:0.870757	valid-auc:0.868788
# [57]	train-auc:0.87101	valid-auc:0.868996
# [58]	train-auc:0.871279	valid-auc:0.869003
# [59]	train-auc:0.87161	valid-auc:0.869033
# [60]	train-auc:0.871717	valid-auc:0.868635
# [61]	train-auc:0.871819	valid-auc:0.868237
# [62]	train-auc:0.871832	valid-auc:0.868485
# [63]	train-auc:0.87225	valid-auc:0.868527
# [64]	train-auc:0.872375	valid-auc:0.868311
# [65]	train-auc:0.872571	valid-auc:0.867865
# [66]	train-auc:0.872918	valid-auc:0.868311
# [67]	train-auc:0.873237	valid-auc:0.868876
# [68]	train-auc:0.873363	valid-auc:0.869061
# [69]	train-auc:0.873536	valid-auc:0.869367
# [70]	train-auc:0.873779	valid-auc:0.869628
# [71]	train-auc:0.873894	valid-auc:0.868647
# [72]	train-auc:0.874217	valid-auc:0.86848
# [73]	train-auc:0.874571	valid-auc:0.869554
# [74]	train-auc:0.874673	valid-auc:0.869161
# [75]	train-auc:0.874845	valid-auc:0.869839
# [76]	train-auc:0.874962	valid-auc:0.870128
# [77]	train-auc:0.874882	valid-auc:0.870309
# [78]	train-auc:0.875202	valid-auc:0.870119
# [79]	train-auc:0.875357	valid-auc:0.870341
# [80]	train-auc:0.875464	valid-auc:0.870857
# [81]	train-auc:0.875622	valid-auc:0.871061
# [82]	train-auc:0.8758	valid-auc:0.870663
# [83]	train-auc:0.875967	valid-auc:0.870598
# [84]	train-auc:0.876041	valid-auc:0.870068
# [85]	train-auc:0.876261	valid-auc:0.870214
# [86]	train-auc:0.876427	valid-auc:0.870343
# [87]	train-auc:0.876595	valid-auc:0.870385
# [88]	train-auc:0.876735	valid-auc:0.870788
# [89]	train-auc:0.876888	valid-auc:0.87086
# [90]	train-auc:0.877093	valid-auc:0.870758
# [91]	train-auc:0.877229	valid-auc:0.87079
# [92]	train-auc:0.877333	valid-auc:0.870947
# [93]	train-auc:0.877507	valid-auc:0.870503
# [94]	train-auc:0.877587	valid-auc:0.870073
# [95]	train-auc:0.87781	valid-auc:0.869489
# [96]	train-auc:0.877931	valid-auc:0.86955
# [97]	train-auc:0.878059	valid-auc:0.869459
# [98]	train-auc:0.878136	valid-auc:0.869552
# [99]	train-auc:0.878054	valid-auc:0.869862
# [100]	train-auc:0.878212	valid-auc:0.869885
# [101]	train-auc:0.878235	valid-auc:0.870026
# Stopping. Best iteration:
# [81]	train-auc:0.875622	valid-auc:0.871061
#
# [0]	train-auc:0.790024	valid-auc:0.787836
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.820885	valid-auc:0.804479
# [2]	train-auc:0.821056	valid-auc:0.810187
# [3]	train-auc:0.833386	valid-auc:0.820761
# [4]	train-auc:0.84424	valid-auc:0.833768
# [5]	train-auc:0.846318	valid-auc:0.839242
# [6]	train-auc:0.84795	valid-auc:0.841874
# [7]	train-auc:0.849169	valid-auc:0.844549
# [8]	train-auc:0.850646	valid-auc:0.843436
# [9]	train-auc:0.850669	valid-auc:0.844248
# [10]	train-auc:0.851641	valid-auc:0.846012
# [11]	train-auc:0.851945	valid-auc:0.846905
# [12]	train-auc:0.856893	valid-auc:0.849157
# [13]	train-auc:0.859552	valid-auc:0.850277
# [14]	train-auc:0.861348	valid-auc:0.850421
# [15]	train-auc:0.861812	valid-auc:0.850354
# [16]	train-auc:0.861644	valid-auc:0.849678
# [17]	train-auc:0.863314	valid-auc:0.851603
# [18]	train-auc:0.864366	valid-auc:0.852735
# [19]	train-auc:0.865471	valid-auc:0.854446
# [20]	train-auc:0.865825	valid-auc:0.856022
# [21]	train-auc:0.866372	valid-auc:0.856283
# [22]	train-auc:0.866592	valid-auc:0.855806
# [23]	train-auc:0.867139	valid-auc:0.85633
# [24]	train-auc:0.867655	valid-auc:0.856603
# [25]	train-auc:0.868153	valid-auc:0.857535
# [26]	train-auc:0.868512	valid-auc:0.858466
# [27]	train-auc:0.868825	valid-auc:0.858408
# [28]	train-auc:0.869894	valid-auc:0.859461
# [29]	train-auc:0.870098	valid-auc:0.859845
# [30]	train-auc:0.870517	valid-auc:0.860514
# [31]	train-auc:0.871101	valid-auc:0.860947
# [32]	train-auc:0.871104	valid-auc:0.861097
# [33]	train-auc:0.871125	valid-auc:0.860894
# [34]	train-auc:0.871846	valid-auc:0.862092
# [35]	train-auc:0.8728	valid-auc:0.862671
# [36]	train-auc:0.873111	valid-auc:0.863016
# [37]	train-auc:0.873822	valid-auc:0.863486
# [38]	train-auc:0.874342	valid-auc:0.863726
# [39]	train-auc:0.875251	valid-auc:0.864134
# [40]	train-auc:0.8757	valid-auc:0.864608
# [41]	train-auc:0.876153	valid-auc:0.863803
# [42]	train-auc:0.87642	valid-auc:0.863113
# [43]	train-auc:0.876714	valid-auc:0.86318
# [44]	train-auc:0.87693	valid-auc:0.862835
# [45]	train-auc:0.877543	valid-auc:0.864305
# [46]	train-auc:0.877954	valid-auc:0.865351
# [47]	train-auc:0.878217	valid-auc:0.865671
# [48]	train-auc:0.87848	valid-auc:0.865955
# [49]	train-auc:0.878749	valid-auc:0.865714
# [50]	train-auc:0.879247	valid-auc:0.865957
# [51]	train-auc:0.879327	valid-auc:0.866809
# [52]	train-auc:0.879481	valid-auc:0.866485
# [53]	train-auc:0.879617	valid-auc:0.867073
# [54]	train-auc:0.87997	valid-auc:0.867552
# [55]	train-auc:0.880138	valid-auc:0.867911
# [56]	train-auc:0.880411	valid-auc:0.868809
# [57]	train-auc:0.880427	valid-auc:0.868621
# [58]	train-auc:0.88072	valid-auc:0.868742
# [59]	train-auc:0.880935	valid-auc:0.868658
# [60]	train-auc:0.881241	valid-auc:0.868682
# [61]	train-auc:0.88149	valid-auc:0.869059
# [62]	train-auc:0.881595	valid-auc:0.869228
# [63]	train-auc:0.881792	valid-auc:0.868853
# [64]	train-auc:0.882014	valid-auc:0.869029
# [65]	train-auc:0.882333	valid-auc:0.869839
# [66]	train-auc:0.882564	valid-auc:0.869904
# [67]	train-auc:0.882641	valid-auc:0.869853
# [68]	train-auc:0.88284	valid-auc:0.869668
# [69]	train-auc:0.883207	valid-auc:0.870135
# [70]	train-auc:0.883434	valid-auc:0.870427
# [71]	train-auc:0.883715	valid-auc:0.870038
# [72]	train-auc:0.883886	valid-auc:0.870172
# [73]	train-auc:0.883903	valid-auc:0.870311
# [74]	train-auc:0.883983	valid-auc:0.870195
# [75]	train-auc:0.884315	valid-auc:0.869936
# [76]	train-auc:0.884466	valid-auc:0.870117
# [77]	train-auc:0.884534	valid-auc:0.870489
# [78]	train-auc:0.884766	valid-auc:0.870299
# [79]	train-auc:0.88499	valid-auc:0.870343
# [80]	train-auc:0.8852	valid-auc:0.870718
# [81]	train-auc:0.885302	valid-auc:0.870802
# [82]	train-auc:0.885645	valid-auc:0.871593
# [83]	train-auc:0.885768	valid-auc:0.871552
# [84]	train-auc:0.885884	valid-auc:0.871269
# [85]	train-auc:0.886174	valid-auc:0.871329
# [86]	train-auc:0.886207	valid-auc:0.871311
# [87]	train-auc:0.8865	valid-auc:0.871387
# [88]	train-auc:0.886685	valid-auc:0.871605
# [89]	train-auc:0.886903	valid-auc:0.871484
# [90]	train-auc:0.887001	valid-auc:0.871406
# [91]	train-auc:0.887204	valid-auc:0.871466
# [92]	train-auc:0.88723	valid-auc:0.871512
# [93]	train-auc:0.887355	valid-auc:0.871813
# [94]	train-auc:0.887419	valid-auc:0.871771
# [95]	train-auc:0.887673	valid-auc:0.871415
# [96]	train-auc:0.887937	valid-auc:0.871244
# [97]	train-auc:0.888079	valid-auc:0.871184
# [98]	train-auc:0.888236	valid-auc:0.87092
# [99]	train-auc:0.888241	valid-auc:0.870846
# [100]	train-auc:0.888476	valid-auc:0.871211
# [101]	train-auc:0.888514	valid-auc:0.871466
# [102]	train-auc:0.888617	valid-auc:0.87141
# [103]	train-auc:0.88871	valid-auc:0.871665
# [104]	train-auc:0.888775	valid-auc:0.871943
# [105]	train-auc:0.889076	valid-auc:0.871734
# [106]	train-auc:0.889314	valid-auc:0.871804
# [107]	train-auc:0.889676	valid-auc:0.871753
# [108]	train-auc:0.889727	valid-auc:0.871808
# [109]	train-auc:0.889889	valid-auc:0.872007
# [110]	train-auc:0.890128	valid-auc:0.872308
# [111]	train-auc:0.890192	valid-auc:0.87229
# [112]	train-auc:0.890347	valid-auc:0.872021
# [113]	train-auc:0.89043	valid-auc:0.872114
# [114]	train-auc:0.890605	valid-auc:0.871827
# [115]	train-auc:0.890695	valid-auc:0.8721
# [116]	train-auc:0.890848	valid-auc:0.871896
# [117]	train-auc:0.89108	valid-auc:0.87191
# [118]	train-auc:0.891185	valid-auc:0.871938
# [119]	train-auc:0.891425	valid-auc:0.871725
# [120]	train-auc:0.891487	valid-auc:0.871628
# [121]	train-auc:0.891615	valid-auc:0.871633
# [122]	train-auc:0.891897	valid-auc:0.871637
# [123]	train-auc:0.891993	valid-auc:0.871767
# [124]	train-auc:0.892073	valid-auc:0.871961
# [125]	train-auc:0.892264	valid-auc:0.871957
# [126]	train-auc:0.892528	valid-auc:0.871623
# [127]	train-auc:0.892581	valid-auc:0.871822
# [128]	train-auc:0.892683	valid-auc:0.871896
# [129]	train-auc:0.893039	valid-auc:0.871725
# [130]	train-auc:0.893067	valid-auc:0.87191
# Stopping. Best iteration:
# [110]	train-auc:0.890128	valid-auc:0.872308
#
# [0]	train-auc:0.810917	valid-auc:0.794622
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.836639	valid-auc:0.824339
# [2]	train-auc:0.844835	valid-auc:0.833262
# [3]	train-auc:0.855371	valid-auc:0.840041
# [4]	train-auc:0.857704	valid-auc:0.843845
# [5]	train-auc:0.858832	valid-auc:0.845331
# [6]	train-auc:0.862694	valid-auc:0.851034
# [7]	train-auc:0.862894	valid-auc:0.850689
# [8]	train-auc:0.863898	valid-auc:0.853147
# [9]	train-auc:0.86388	valid-auc:0.85233
# [10]	train-auc:0.868543	valid-auc:0.855385
# [11]	train-auc:0.8692	valid-auc:0.857501
# [12]	train-auc:0.869178	valid-auc:0.858158
# [13]	train-auc:0.871452	valid-auc:0.859968
# [14]	train-auc:0.872679	valid-auc:0.86116
# [15]	train-auc:0.87312	valid-auc:0.861891
# [16]	train-auc:0.873556	valid-auc:0.861947
# [17]	train-auc:0.873919	valid-auc:0.862289
# [18]	train-auc:0.875165	valid-auc:0.862187
# [19]	train-auc:0.876407	valid-auc:0.864509
# [20]	train-auc:0.877316	valid-auc:0.864974
# [21]	train-auc:0.877446	valid-auc:0.865495
# [22]	train-auc:0.878067	valid-auc:0.866205
# [23]	train-auc:0.87843	valid-auc:0.866483
# [24]	train-auc:0.878789	valid-auc:0.865726
# [25]	train-auc:0.879498	valid-auc:0.866427
# [26]	train-auc:0.879744	valid-auc:0.866978
# [27]	train-auc:0.879958	valid-auc:0.867348
# [28]	train-auc:0.880184	valid-auc:0.867043
# [29]	train-auc:0.881226	valid-auc:0.866548
# [30]	train-auc:0.881488	valid-auc:0.866249
# [31]	train-auc:0.881983	valid-auc:0.866411
# [32]	train-auc:0.882097	valid-auc:0.866444
# [33]	train-auc:0.882529	valid-auc:0.866974
# [34]	train-auc:0.882659	valid-auc:0.867367
# [35]	train-auc:0.883122	valid-auc:0.867457
# [36]	train-auc:0.883452	valid-auc:0.867214
# [37]	train-auc:0.883958	valid-auc:0.867744
# [38]	train-auc:0.884219	valid-auc:0.867527
# [39]	train-auc:0.884573	valid-auc:0.868182
# [40]	train-auc:0.884856	valid-auc:0.868575
# [41]	train-auc:0.885088	valid-auc:0.868133
# [42]	train-auc:0.88536	valid-auc:0.867716
# [43]	train-auc:0.88599	valid-auc:0.868124
# [44]	train-auc:0.886343	valid-auc:0.867883
# [45]	train-auc:0.886495	valid-auc:0.868522
# [46]	train-auc:0.887037	valid-auc:0.868733
# [47]	train-auc:0.887227	valid-auc:0.86826
# [48]	train-auc:0.887421	valid-auc:0.868575
# [49]	train-auc:0.887621	valid-auc:0.868587
# [50]	train-auc:0.887763	valid-auc:0.868226
# [51]	train-auc:0.888083	valid-auc:0.868665
# [52]	train-auc:0.888354	valid-auc:0.868432
# [53]	train-auc:0.888537	valid-auc:0.868284
# [54]	train-auc:0.888972	valid-auc:0.868631
# [55]	train-auc:0.889135	valid-auc:0.868927
# [56]	train-auc:0.889383	valid-auc:0.868744
# [57]	train-auc:0.889535	valid-auc:0.869082
# [58]	train-auc:0.889899	valid-auc:0.869193
# [59]	train-auc:0.8901	valid-auc:0.869573
# [60]	train-auc:0.890385	valid-auc:0.86942
# [61]	train-auc:0.890542	valid-auc:0.869735
# [62]	train-auc:0.890686	valid-auc:0.870248
# [63]	train-auc:0.890802	valid-auc:0.870461
# [64]	train-auc:0.891187	valid-auc:0.870489
# [65]	train-auc:0.891537	valid-auc:0.870295
# [66]	train-auc:0.891712	valid-auc:0.870406
# [67]	train-auc:0.891892	valid-auc:0.870577
# [68]	train-auc:0.892044	valid-auc:0.870512
# [69]	train-auc:0.892354	valid-auc:0.870767
# [70]	train-auc:0.892499	valid-auc:0.871299
# [71]	train-auc:0.892741	valid-auc:0.870818
# [72]	train-auc:0.892873	valid-auc:0.870735
# [73]	train-auc:0.892931	valid-auc:0.871059
# [74]	train-auc:0.893105	valid-auc:0.870873
# [75]	train-auc:0.893712	valid-auc:0.870908
# [76]	train-auc:0.894053	valid-auc:0.870441
# [77]	train-auc:0.894224	valid-auc:0.870672
# [78]	train-auc:0.894462	valid-auc:0.870561
# [79]	train-auc:0.89454	valid-auc:0.870723
# [80]	train-auc:0.894855	valid-auc:0.871596
# [81]	train-auc:0.894923	valid-auc:0.871531
# [82]	train-auc:0.895295	valid-auc:0.872012
# [83]	train-auc:0.895482	valid-auc:0.872026
# [84]	train-auc:0.89574	valid-auc:0.871859
# [85]	train-auc:0.895939	valid-auc:0.871508
# [86]	train-auc:0.896043	valid-auc:0.871646
# [87]	train-auc:0.896097	valid-auc:0.87166
# [88]	train-auc:0.896244	valid-auc:0.872165
# [89]	train-auc:0.896534	valid-auc:0.872197
# [90]	train-auc:0.896801	valid-auc:0.871795
# [91]	train-auc:0.897163	valid-auc:0.872007
# [92]	train-auc:0.897568	valid-auc:0.871799
# [93]	train-auc:0.897823	valid-auc:0.871535
# [94]	train-auc:0.898032	valid-auc:0.871716
# [95]	train-auc:0.898213	valid-auc:0.871702
# [96]	train-auc:0.89853	valid-auc:0.871545
# [97]	train-auc:0.898677	valid-auc:0.871558
# [98]	train-auc:0.898901	valid-auc:0.871415
# [99]	train-auc:0.899002	valid-auc:0.871609
# [100]	train-auc:0.899375	valid-auc:0.871109
# [101]	train-auc:0.899452	valid-auc:0.871276
# [102]	train-auc:0.899551	valid-auc:0.871234
# [103]	train-auc:0.899676	valid-auc:0.871623
# [104]	train-auc:0.899864	valid-auc:0.871526
# [105]	train-auc:0.900034	valid-auc:0.871531
# [106]	train-auc:0.90043	valid-auc:0.87141
# [107]	train-auc:0.900677	valid-auc:0.871471
# [108]	train-auc:0.900732	valid-auc:0.871383
# [109]	train-auc:0.900823	valid-auc:0.871674
# Stopping. Best iteration:
# [89]	train-auc:0.896534	valid-auc:0.872197
#
# [0]	train-auc:0.755108	valid-auc:0.762223
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.79242	valid-auc:0.796664
# [2]	train-auc:0.80176	valid-auc:0.809548
# [3]	train-auc:0.815347	valid-auc:0.818461
# [4]	train-auc:0.826543	valid-auc:0.835694
# [5]	train-auc:0.831917	valid-auc:0.841309
# [6]	train-auc:0.83437	valid-auc:0.842186
# [7]	train-auc:0.836681	valid-auc:0.844882
# [8]	train-auc:0.837834	valid-auc:0.845847
# [9]	train-auc:0.841284	valid-auc:0.848083
# [10]	train-auc:0.841576	valid-auc:0.849287
# [11]	train-auc:0.847894	valid-auc:0.853281
# [12]	train-auc:0.848391	valid-auc:0.853943
# [13]	train-auc:0.852915	valid-auc:0.858406
# [14]	train-auc:0.853684	valid-auc:0.859685
# [15]	train-auc:0.855544	valid-auc:0.861699
# [16]	train-auc:0.856832	valid-auc:0.860877
# [17]	train-auc:0.858735	valid-auc:0.861743
# [18]	train-auc:0.860884	valid-auc:0.862585
# [19]	train-auc:0.861799	valid-auc:0.864217
# [20]	train-auc:0.861355	valid-auc:0.864085
# [21]	train-auc:0.863111	valid-auc:0.863645
# [22]	train-auc:0.865259	valid-auc:0.864259
# [23]	train-auc:0.865827	valid-auc:0.865643
# [24]	train-auc:0.866564	valid-auc:0.863611
# [25]	train-auc:0.867714	valid-auc:0.866409
# [26]	train-auc:0.868138	valid-auc:0.8682
# [27]	train-auc:0.868076	valid-auc:0.868825
# [28]	train-auc:0.868846	valid-auc:0.869688
# [29]	train-auc:0.869245	valid-auc:0.868885
# [30]	train-auc:0.869507	valid-auc:0.868448
# [31]	train-auc:0.870303	valid-auc:0.868855
# [32]	train-auc:0.870506	valid-auc:0.869128
# [33]	train-auc:0.870745	valid-auc:0.868552
# [34]	train-auc:0.87138	valid-auc:0.868869
# [35]	train-auc:0.87223	valid-auc:0.867862
# [36]	train-auc:0.872435	valid-auc:0.867177
# [37]	train-auc:0.872689	valid-auc:0.866411
# [38]	train-auc:0.873248	valid-auc:0.866342
# [39]	train-auc:0.873696	valid-auc:0.866207
# [40]	train-auc:0.873903	valid-auc:0.86655
# [41]	train-auc:0.874378	valid-auc:0.867029
# [42]	train-auc:0.874175	valid-auc:0.867073
# [43]	train-auc:0.874606	valid-auc:0.866828
# [44]	train-auc:0.874794	valid-auc:0.866814
# [45]	train-auc:0.87517	valid-auc:0.867814
# [46]	train-auc:0.875406	valid-auc:0.869054
# [47]	train-auc:0.875488	valid-auc:0.869924
# [48]	train-auc:0.875618	valid-auc:0.870001
# [49]	train-auc:0.875815	valid-auc:0.870172
# [50]	train-auc:0.876181	valid-auc:0.869959
# [51]	train-auc:0.876237	valid-auc:0.870459
# [52]	train-auc:0.876419	valid-auc:0.869797
# [53]	train-auc:0.876618	valid-auc:0.869607
# [54]	train-auc:0.876623	valid-auc:0.869871
# [55]	train-auc:0.877224	valid-auc:0.869556
# [56]	train-auc:0.877532	valid-auc:0.869968
# [57]	train-auc:0.877802	valid-auc:0.870043
# [58]	train-auc:0.878014	valid-auc:0.869846
# [59]	train-auc:0.87813	valid-auc:0.870096
# [60]	train-auc:0.878336	valid-auc:0.869633
# [61]	train-auc:0.878451	valid-auc:0.869281
# [62]	train-auc:0.878568	valid-auc:0.869337
# [63]	train-auc:0.878917	valid-auc:0.869263
# [64]	train-auc:0.879346	valid-auc:0.868864
# [65]	train-auc:0.87961	valid-auc:0.868908
# [66]	train-auc:0.879687	valid-auc:0.868811
# [67]	train-auc:0.879786	valid-auc:0.869043
# [68]	train-auc:0.879922	valid-auc:0.869121
# [69]	train-auc:0.880045	valid-auc:0.869492
# [70]	train-auc:0.880236	valid-auc:0.869955
# [71]	train-auc:0.880331	valid-auc:0.870306
# Stopping. Best iteration:
# [51]	train-auc:0.876237	valid-auc:0.870459
#
# [0]	train-auc:0.790024	valid-auc:0.787836
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.821565	valid-auc:0.803683
# [2]	train-auc:0.823795	valid-auc:0.815702
# [3]	train-auc:0.838968	valid-auc:0.828056
# [4]	train-auc:0.848164	valid-auc:0.841047
# [5]	train-auc:0.856623	valid-auc:0.845882
# [6]	train-auc:0.859038	valid-auc:0.850004
# [7]	train-auc:0.85915	valid-auc:0.849814
# [8]	train-auc:0.860797	valid-auc:0.851108
# [9]	train-auc:0.863472	valid-auc:0.851312
# [10]	train-auc:0.864972	valid-auc:0.852453
# [11]	train-auc:0.865941	valid-auc:0.854774
# [12]	train-auc:0.868196	valid-auc:0.857429
# [13]	train-auc:0.869591	valid-auc:0.857542
# [14]	train-auc:0.868899	valid-auc:0.85801
# [15]	train-auc:0.871468	valid-auc:0.859123
# [16]	train-auc:0.872206	valid-auc:0.858482
# [17]	train-auc:0.87439	valid-auc:0.859861
# [18]	train-auc:0.874161	valid-auc:0.859954
# [19]	train-auc:0.874912	valid-auc:0.86134
# [20]	train-auc:0.875327	valid-auc:0.861505
# [21]	train-auc:0.876887	valid-auc:0.862912
# [22]	train-auc:0.877297	valid-auc:0.862703
# [23]	train-auc:0.877549	valid-auc:0.862035
# [24]	train-auc:0.878396	valid-auc:0.860322
# [25]	train-auc:0.878776	valid-auc:0.860634
# [26]	train-auc:0.87921	valid-auc:0.864421
# [27]	train-auc:0.879641	valid-auc:0.865497
# [28]	train-auc:0.880048	valid-auc:0.864523
# [29]	train-auc:0.880714	valid-auc:0.864363
# [30]	train-auc:0.881276	valid-auc:0.863912
# [31]	train-auc:0.882063	valid-auc:0.864979
# [32]	train-auc:0.882232	valid-auc:0.865205
# [33]	train-auc:0.8827	valid-auc:0.865471
# [34]	train-auc:0.883026	valid-auc:0.865608
# [35]	train-auc:0.883345	valid-auc:0.865439
# [36]	train-auc:0.883532	valid-auc:0.865596
# [37]	train-auc:0.884228	valid-auc:0.865731
# [38]	train-auc:0.884478	valid-auc:0.865377
# [39]	train-auc:0.884614	valid-auc:0.865016
# [40]	train-auc:0.884658	valid-auc:0.865636
# [41]	train-auc:0.884815	valid-auc:0.866358
# [42]	train-auc:0.885064	valid-auc:0.866096
# [43]	train-auc:0.885846	valid-auc:0.865638
# [44]	train-auc:0.886201	valid-auc:0.865765
# [45]	train-auc:0.88643	valid-auc:0.866089
# [46]	train-auc:0.886938	valid-auc:0.865423
# [47]	train-auc:0.887358	valid-auc:0.865779
# [48]	train-auc:0.887643	valid-auc:0.865529
# [49]	train-auc:0.887805	valid-auc:0.866187
# [50]	train-auc:0.888047	valid-auc:0.8659
# [51]	train-auc:0.888105	valid-auc:0.866217
# [52]	train-auc:0.88833	valid-auc:0.865712
# [53]	train-auc:0.888445	valid-auc:0.86562
# [54]	train-auc:0.888704	valid-auc:0.866152
# [55]	train-auc:0.889151	valid-auc:0.865828
# [56]	train-auc:0.889452	valid-auc:0.866175
# [57]	train-auc:0.88997	valid-auc:0.866055
# [58]	train-auc:0.890134	valid-auc:0.865756
# [59]	train-auc:0.890233	valid-auc:0.866349
# [60]	train-auc:0.890436	valid-auc:0.866418
# [61]	train-auc:0.891014	valid-auc:0.866367
# [62]	train-auc:0.891738	valid-auc:0.86615
# [63]	train-auc:0.891962	valid-auc:0.866117
# [64]	train-auc:0.892651	valid-auc:0.866404
# [65]	train-auc:0.893174	valid-auc:0.86608
# [66]	train-auc:0.893519	valid-auc:0.866279
# [67]	train-auc:0.893644	valid-auc:0.866407
# [68]	train-auc:0.893835	valid-auc:0.866323
# [69]	train-auc:0.894339	valid-auc:0.866536
# [70]	train-auc:0.894345	valid-auc:0.867018
# [71]	train-auc:0.89446	valid-auc:0.867133
# [72]	train-auc:0.894692	valid-auc:0.866943
# [73]	train-auc:0.8949	valid-auc:0.866707
# [74]	train-auc:0.895219	valid-auc:0.867355
# [75]	train-auc:0.895665	valid-auc:0.867018
# [76]	train-auc:0.895941	valid-auc:0.866786
# [77]	train-auc:0.896096	valid-auc:0.86649
# [78]	train-auc:0.896491	valid-auc:0.865828
# [79]	train-auc:0.896692	valid-auc:0.865883
# [80]	train-auc:0.896843	valid-auc:0.865694
# [81]	train-auc:0.896992	valid-auc:0.865606
# [82]	train-auc:0.897398	valid-auc:0.865962
# [83]	train-auc:0.897575	valid-auc:0.866045
# [84]	train-auc:0.897592	valid-auc:0.865902
# [85]	train-auc:0.897768	valid-auc:0.865583
# [86]	train-auc:0.897782	valid-auc:0.865694
# [87]	train-auc:0.897782	valid-auc:0.865708
# [88]	train-auc:0.89834	valid-auc:0.865717
# [89]	train-auc:0.898809	valid-auc:0.865893
# [90]	train-auc:0.899065	valid-auc:0.865694
# [91]	train-auc:0.899286	valid-auc:0.865212
# [92]	train-auc:0.899496	valid-auc:0.864833
# [93]	train-auc:0.899666	valid-auc:0.865263
# [94]	train-auc:0.899773	valid-auc:0.865536
# Stopping. Best iteration:
# [74]	train-auc:0.895219	valid-auc:0.867355
#
# [0]	train-auc:0.810917	valid-auc:0.794622
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.839125	valid-auc:0.827195
# [2]	train-auc:0.846385	valid-auc:0.842755
# [3]	train-auc:0.857449	valid-auc:0.845933
# [4]	train-auc:0.862114	valid-auc:0.853212
# [5]	train-auc:0.86723	valid-auc:0.85797
# [6]	train-auc:0.8684	valid-auc:0.858998
# [7]	train-auc:0.871081	valid-auc:0.860866
# [8]	train-auc:0.872396	valid-auc:0.861157
# [9]	train-auc:0.872847	valid-auc:0.859822
# [10]	train-auc:0.874494	valid-auc:0.861426
# [11]	train-auc:0.876726	valid-auc:0.863962
# [12]	train-auc:0.878575	valid-auc:0.865201
# [13]	train-auc:0.879549	valid-auc:0.865555
# [14]	train-auc:0.880535	valid-auc:0.866411
# [15]	train-auc:0.880742	valid-auc:0.866131
# [16]	train-auc:0.88143	valid-auc:0.866409
# [17]	train-auc:0.882353	valid-auc:0.867478
# [18]	train-auc:0.882806	valid-auc:0.86617
# [19]	train-auc:0.883087	valid-auc:0.867742
# [20]	train-auc:0.883681	valid-auc:0.869063
# [21]	train-auc:0.88465	valid-auc:0.867899
# [22]	train-auc:0.885269	valid-auc:0.867277
# [23]	train-auc:0.885586	valid-auc:0.866656
# [24]	train-auc:0.886414	valid-auc:0.865768
# [25]	train-auc:0.886926	valid-auc:0.865756
# [26]	train-auc:0.887545	valid-auc:0.867541
# [27]	train-auc:0.887964	valid-auc:0.868418
# [28]	train-auc:0.888621	valid-auc:0.867862
# [29]	train-auc:0.889111	valid-auc:0.867969
# [30]	train-auc:0.889736	valid-auc:0.868358
# [31]	train-auc:0.890079	valid-auc:0.868237
# [32]	train-auc:0.890299	valid-auc:0.868649
# [33]	train-auc:0.890745	valid-auc:0.868228
# [34]	train-auc:0.891676	valid-auc:0.867605
# [35]	train-auc:0.892191	valid-auc:0.867844
# [36]	train-auc:0.892509	valid-auc:0.868052
# [37]	train-auc:0.892945	valid-auc:0.868418
# [38]	train-auc:0.893352	valid-auc:0.869098
# [39]	train-auc:0.893628	valid-auc:0.868913
# [40]	train-auc:0.893817	valid-auc:0.868061
# [41]	train-auc:0.894334	valid-auc:0.86774
# [42]	train-auc:0.894748	valid-auc:0.867258
# [43]	train-auc:0.895208	valid-auc:0.867767
# [44]	train-auc:0.895797	valid-auc:0.867862
# [45]	train-auc:0.896302	valid-auc:0.867987
# [46]	train-auc:0.897089	valid-auc:0.867714
# [47]	train-auc:0.897382	valid-auc:0.867742
# [48]	train-auc:0.897787	valid-auc:0.867899
# [49]	train-auc:0.898143	valid-auc:0.867867
# [50]	train-auc:0.898747	valid-auc:0.867608
# [51]	train-auc:0.898964	valid-auc:0.867969
# [52]	train-auc:0.899709	valid-auc:0.868395
# [53]	train-auc:0.89989	valid-auc:0.868608
# [54]	train-auc:0.899991	valid-auc:0.868515
# [55]	train-auc:0.900412	valid-auc:0.868459
# [56]	train-auc:0.900682	valid-auc:0.86933
# [57]	train-auc:0.900954	valid-auc:0.868358
# [58]	train-auc:0.901776	valid-auc:0.868818
# [59]	train-auc:0.901968	valid-auc:0.86911
# [60]	train-auc:0.902384	valid-auc:0.868675
# [61]	train-auc:0.902604	valid-auc:0.86829
# [62]	train-auc:0.90309	valid-auc:0.868777
# [63]	train-auc:0.90342	valid-auc:0.869073
# [64]	train-auc:0.904115	valid-auc:0.868744
# [65]	train-auc:0.904632	valid-auc:0.86848
# [66]	train-auc:0.904881	valid-auc:0.868531
# [67]	train-auc:0.90528	valid-auc:0.868864
# [68]	train-auc:0.905583	valid-auc:0.868527
# [69]	train-auc:0.905976	valid-auc:0.868471
# [70]	train-auc:0.906186	valid-auc:0.86923
# [71]	train-auc:0.906421	valid-auc:0.86955
# [72]	train-auc:0.90678	valid-auc:0.869369
# [73]	train-auc:0.907244	valid-auc:0.869721
# [74]	train-auc:0.907622	valid-auc:0.869489
# [75]	train-auc:0.908043	valid-auc:0.869101
# [76]	train-auc:0.90854	valid-auc:0.869406
# [77]	train-auc:0.90866	valid-auc:0.869202
# [78]	train-auc:0.908853	valid-auc:0.868614
# [79]	train-auc:0.9089	valid-auc:0.868471
# [80]	train-auc:0.908981	valid-auc:0.869068
# [81]	train-auc:0.909055	valid-auc:0.869184
# [82]	train-auc:0.909456	valid-auc:0.869114
# [83]	train-auc:0.909549	valid-auc:0.869184
# [84]	train-auc:0.909959	valid-auc:0.869605
# [85]	train-auc:0.910235	valid-auc:0.869045
# [86]	train-auc:0.91045	valid-auc:0.869128
# [87]	train-auc:0.910729	valid-auc:0.868985
# [88]	train-auc:0.911083	valid-auc:0.869082
# [89]	train-auc:0.911228	valid-auc:0.869429
# [90]	train-auc:0.911551	valid-auc:0.869008
# [91]	train-auc:0.911678	valid-auc:0.868818
# [92]	train-auc:0.911926	valid-auc:0.869499
# [93]	train-auc:0.912167	valid-auc:0.869202
# Stopping. Best iteration:
# [73]	train-auc:0.907244	valid-auc:0.869721
#
# [0]	train-auc:0.755108	valid-auc:0.762223
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.778613	valid-auc:0.77944
# [2]	train-auc:0.803951	valid-auc:0.800135
# [3]	train-auc:0.818433	valid-auc:0.807275
# [4]	train-auc:0.832582	valid-auc:0.833042
# [5]	train-auc:0.832946	valid-auc:0.836685
# [6]	train-auc:0.844905	valid-auc:0.841721
# [7]	train-auc:0.845746	valid-auc:0.846743
# [8]	train-auc:0.849008	valid-auc:0.853513
# [9]	train-auc:0.849596	valid-auc:0.854658
# [10]	train-auc:0.853894	valid-auc:0.855341
# [11]	train-auc:0.85887	valid-auc:0.858535
# [12]	train-auc:0.860267	valid-auc:0.860965
# [13]	train-auc:0.862826	valid-auc:0.862301
# [14]	train-auc:0.863162	valid-auc:0.862433
# [15]	train-auc:0.864101	valid-auc:0.864798
# [16]	train-auc:0.865291	valid-auc:0.864682
# [17]	train-auc:0.866235	valid-auc:0.863324
# [18]	train-auc:0.867774	valid-auc:0.863361
# [19]	train-auc:0.868502	valid-auc:0.861701
# [20]	train-auc:0.869183	valid-auc:0.861046
# [21]	train-auc:0.870035	valid-auc:0.864233
# [22]	train-auc:0.871175	valid-auc:0.862847
# [23]	train-auc:0.871205	valid-auc:0.862865
# [24]	train-auc:0.871998	valid-auc:0.864259
# [25]	train-auc:0.872849	valid-auc:0.864166
# [26]	train-auc:0.873423	valid-auc:0.865789
# [27]	train-auc:0.873693	valid-auc:0.866096
# [28]	train-auc:0.873775	valid-auc:0.866013
# [29]	train-auc:0.874003	valid-auc:0.864948
# [30]	train-auc:0.874391	valid-auc:0.864372
# [31]	train-auc:0.875107	valid-auc:0.864233
# [32]	train-auc:0.875488	valid-auc:0.864953
# [33]	train-auc:0.875498	valid-auc:0.86493
# [34]	train-auc:0.875911	valid-auc:0.864921
# [35]	train-auc:0.876328	valid-auc:0.86477
# [36]	train-auc:0.876415	valid-auc:0.864349
# [37]	train-auc:0.876758	valid-auc:0.865029
# [38]	train-auc:0.877102	valid-auc:0.865613
# [39]	train-auc:0.87749	valid-auc:0.86617
# [40]	train-auc:0.877897	valid-auc:0.866279
# [41]	train-auc:0.878656	valid-auc:0.866749
# [42]	train-auc:0.878794	valid-auc:0.866258
# [43]	train-auc:0.879126	valid-auc:0.866758
# [44]	train-auc:0.87958	valid-auc:0.866365
# [45]	train-auc:0.880411	valid-auc:0.866513
# [46]	train-auc:0.880916	valid-auc:0.865971
# [47]	train-auc:0.881241	valid-auc:0.865184
# [48]	train-auc:0.881369	valid-auc:0.865249
# [49]	train-auc:0.881506	valid-auc:0.865978
# [50]	train-auc:0.88168	valid-auc:0.865779
# [51]	train-auc:0.881918	valid-auc:0.86639
# [52]	train-auc:0.88196	valid-auc:0.865839
# [53]	train-auc:0.881968	valid-auc:0.86583
# [54]	train-auc:0.882106	valid-auc:0.866562
# [55]	train-auc:0.882814	valid-auc:0.866163
# [56]	train-auc:0.883253	valid-auc:0.867186
# [57]	train-auc:0.883721	valid-auc:0.866918
# [58]	train-auc:0.883719	valid-auc:0.867136
# [59]	train-auc:0.883921	valid-auc:0.866974
# [60]	train-auc:0.884077	valid-auc:0.867163
# [61]	train-auc:0.88428	valid-auc:0.866802
# [62]	train-auc:0.884521	valid-auc:0.867001
# [63]	train-auc:0.884715	valid-auc:0.867673
# [64]	train-auc:0.885104	valid-auc:0.868015
# [65]	train-auc:0.885573	valid-auc:0.867538
# [66]	train-auc:0.885793	valid-auc:0.867413
# [67]	train-auc:0.885919	valid-auc:0.868432
# [68]	train-auc:0.886038	valid-auc:0.868839
# [69]	train-auc:0.886397	valid-auc:0.869515
# [70]	train-auc:0.886509	valid-auc:0.869894
# [71]	train-auc:0.886549	valid-auc:0.870029
# [72]	train-auc:0.886904	valid-auc:0.869894
# [73]	train-auc:0.887398	valid-auc:0.870561
# [74]	train-auc:0.887811	valid-auc:0.870181
# [75]	train-auc:0.888123	valid-auc:0.870144
# [76]	train-auc:0.888309	valid-auc:0.870209
# [77]	train-auc:0.888425	valid-auc:0.870339
# [78]	train-auc:0.888465	valid-auc:0.869603
# [79]	train-auc:0.888418	valid-auc:0.870209
# [80]	train-auc:0.888383	valid-auc:0.869728
# [81]	train-auc:0.888444	valid-auc:0.869922
# [82]	train-auc:0.888931	valid-auc:0.870015
# [83]	train-auc:0.889105	valid-auc:0.869992
# [84]	train-auc:0.889359	valid-auc:0.869876
# [85]	train-auc:0.889798	valid-auc:0.869501
# [86]	train-auc:0.890108	valid-auc:0.869288
# [87]	train-auc:0.890371	valid-auc:0.869209
# [88]	train-auc:0.890668	valid-auc:0.869029
# [89]	train-auc:0.890807	valid-auc:0.868742
# [90]	train-auc:0.891088	valid-auc:0.867441
# [91]	train-auc:0.891187	valid-auc:0.867293
# [92]	train-auc:0.891304	valid-auc:0.867983
# [93]	train-auc:0.891583	valid-auc:0.86751
# Stopping. Best iteration:
# [73]	train-auc:0.887398	valid-auc:0.870561
#
# [0]	train-auc:0.790024	valid-auc:0.787836
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.821101	valid-auc:0.814172
# [2]	train-auc:0.835944	valid-auc:0.828746
# [3]	train-auc:0.848173	valid-auc:0.841279
# [4]	train-auc:0.854801	valid-auc:0.847097
# [5]	train-auc:0.858775	valid-auc:0.847324
# [6]	train-auc:0.864077	valid-auc:0.851946
# [7]	train-auc:0.865502	valid-auc:0.853036
# [8]	train-auc:0.865858	valid-auc:0.857068
# [9]	train-auc:0.86652	valid-auc:0.858193
# [10]	train-auc:0.870516	valid-auc:0.861708
# [11]	train-auc:0.87345	valid-auc:0.863085
# [12]	train-auc:0.87438	valid-auc:0.863171
# [13]	train-auc:0.875145	valid-auc:0.863041
# [14]	train-auc:0.875797	valid-auc:0.861315
# [15]	train-auc:0.876563	valid-auc:0.862643
# [16]	train-auc:0.878268	valid-auc:0.86375
# [17]	train-auc:0.878872	valid-auc:0.864488
# [18]	train-auc:0.879873	valid-auc:0.864113
# [19]	train-auc:0.880399	valid-auc:0.865911
# [20]	train-auc:0.881401	valid-auc:0.866555
# [21]	train-auc:0.881849	valid-auc:0.867913
# [22]	train-auc:0.882704	valid-auc:0.868152
# [23]	train-auc:0.883535	valid-auc:0.868429
# [24]	train-auc:0.88438	valid-auc:0.868205
# [25]	train-auc:0.884746	valid-auc:0.868883
# [26]	train-auc:0.885753	valid-auc:0.870411
# [27]	train-auc:0.885963	valid-auc:0.87079
# [28]	train-auc:0.886418	valid-auc:0.870739
# [29]	train-auc:0.886385	valid-auc:0.870665
# [30]	train-auc:0.886738	valid-auc:0.871193
# [31]	train-auc:0.887195	valid-auc:0.87051
# [32]	train-auc:0.887651	valid-auc:0.871281
# [33]	train-auc:0.888238	valid-auc:0.871825
# [34]	train-auc:0.889005	valid-auc:0.872674
# [35]	train-auc:0.889447	valid-auc:0.872225
# [36]	train-auc:0.889645	valid-auc:0.872207
# [37]	train-auc:0.890147	valid-auc:0.871304
# [38]	train-auc:0.890585	valid-auc:0.871491
# [39]	train-auc:0.890956	valid-auc:0.87063
# [40]	train-auc:0.891346	valid-auc:0.871126
# [41]	train-auc:0.891917	valid-auc:0.870959
# [42]	train-auc:0.892301	valid-auc:0.870644
# [43]	train-auc:0.892679	valid-auc:0.870987
# [44]	train-auc:0.892916	valid-auc:0.870311
# [45]	train-auc:0.893589	valid-auc:0.870098
# [46]	train-auc:0.893999	valid-auc:0.870015
# [47]	train-auc:0.894334	valid-auc:0.870547
# [48]	train-auc:0.894461	valid-auc:0.870755
# [49]	train-auc:0.894661	valid-auc:0.871065
# [50]	train-auc:0.895155	valid-auc:0.869941
# [51]	train-auc:0.895419	valid-auc:0.869441
# [52]	train-auc:0.896236	valid-auc:0.86926
# [53]	train-auc:0.896902	valid-auc:0.870098
# [54]	train-auc:0.896899	valid-auc:0.870737
# Stopping. Best iteration:
# [34]	train-auc:0.889005	valid-auc:0.872674
#
# [0]	train-auc:0.810917	valid-auc:0.794622
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.855132	valid-auc:0.839663
# [2]	train-auc:0.860838	valid-auc:0.847886
# [3]	train-auc:0.868495	valid-auc:0.856209
# [4]	train-auc:0.870232	valid-auc:0.85926
# [5]	train-auc:0.872294	valid-auc:0.863192
# [6]	train-auc:0.874092	valid-auc:0.866652
# [7]	train-auc:0.8759	valid-auc:0.867316
# [8]	train-auc:0.877926	valid-auc:0.868591
# [9]	train-auc:0.878177	valid-auc:0.868665
# [10]	train-auc:0.879215	valid-auc:0.868802
# [11]	train-auc:0.881405	valid-auc:0.870947
# [12]	train-auc:0.883337	valid-auc:0.872456
# [13]	train-auc:0.88422	valid-auc:0.872804
# [14]	train-auc:0.884606	valid-auc:0.871808
# [15]	train-auc:0.885458	valid-auc:0.873889
# [16]	train-auc:0.886673	valid-auc:0.873304
# [17]	train-auc:0.887341	valid-auc:0.873459
# [18]	train-auc:0.8882	valid-auc:0.872618
# [19]	train-auc:0.889022	valid-auc:0.873827
# [20]	train-auc:0.889432	valid-auc:0.87248
# [21]	train-auc:0.890161	valid-auc:0.873924
# [22]	train-auc:0.89036	valid-auc:0.874579
# [23]	train-auc:0.891515	valid-auc:0.873472
# [24]	train-auc:0.892683	valid-auc:0.873276
# [25]	train-auc:0.894114	valid-auc:0.873477
# [26]	train-auc:0.894667	valid-auc:0.87403
# [27]	train-auc:0.895469	valid-auc:0.873225
# [28]	train-auc:0.895724	valid-auc:0.873674
# [29]	train-auc:0.896411	valid-auc:0.872783
# [30]	train-auc:0.896849	valid-auc:0.873227
# [31]	train-auc:0.897336	valid-auc:0.872922
# [32]	train-auc:0.897466	valid-auc:0.872186
# [33]	train-auc:0.897821	valid-auc:0.872227
# [34]	train-auc:0.898843	valid-auc:0.872454
# [35]	train-auc:0.899007	valid-auc:0.872514
# [36]	train-auc:0.899315	valid-auc:0.872412
# [37]	train-auc:0.900109	valid-auc:0.870709
# [38]	train-auc:0.900822	valid-auc:0.870029
# [39]	train-auc:0.901313	valid-auc:0.869769
# [40]	train-auc:0.901661	valid-auc:0.870422
# [41]	train-auc:0.902226	valid-auc:0.870626
# [42]	train-auc:0.902395	valid-auc:0.870103
# Stopping. Best iteration:
# [22]	train-auc:0.89036	valid-auc:0.874579

# %%
display(result)
# Out:
#    eta  max_depth  gini_train  gini_valid  difference
# 0  0.1          2    0.751245    0.742122    0.009123
# 0  0.1          3    0.780257    0.744617    0.035640
# 0  0.1          4    0.793067    0.744394    0.048673
# 0  0.2          2    0.752474    0.740918    0.011556
# 0  0.2          3    0.790439    0.734711    0.055728
# 0  0.2          4    0.814488    0.739442    0.075046
# 0  0.3          2    0.774795    0.741122    0.033673
# 0  0.3          3    0.778011    0.745348    0.032663
# 0  0.3          4    0.780719    0.749158    0.031561

# %%
best_valid = result.loc[result['gini_valid'] == result['gini_valid'].max(),['eta', 'max_depth']].to_dict('list')
best_diff = result.loc[result['difference'] == result['difference'].min(),['eta', 'max_depth']].to_dict('list')

print('hyperparameter for best_valid: ', best_valid)
print('hyperparameter for best_diff, ', best_diff)
# Out:
# hyperparameter for best_valid:  {'eta': [0.3], 'max_depth': [4]}
# hyperparameter for best_diff,  {'eta': [0.1], 'max_depth': [2]}

# %% [markdown]
# ### Final Model

# %%
import xgboost as xgb

dt_xgb = data[pred_xgb]
tuning = best_diff # set hyperparameter

xgb_params = {'eta': tuning.get('eta')[0],
    'max_depth': tuning.get('max_depth')[0],
    'objective': 'binary:logistic',
    'eval_metric': 'auc',
    'min_child_weight': 30,
    'subsample': 0.85}

evals_result = {}

fbooster = xgb.train(params = xgb_params,
                        dtrain = xgb.DMatrix(dt_xgb[train_mask],data[train_mask][col_target]),
                        num_boost_round = 500,
                        early_stopping_rounds = 20,
                        evals = ((xgb.DMatrix(dt_xgb[train_mask],data[train_mask][col_target]),'train'),
                                 (xgb.DMatrix(dt_xgb[valid_mask],data[valid_mask][col_target]),'valid')
                                ), 
                        evals_result = evals_result,)

fxgb_scored = fbooster.predict(xgb.DMatrix(dt_xgb), ntree_limit=fbooster.best_ntree_limit)
# Out:
# [0]	train-auc:0.755108	valid-auc:0.762223
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.79242	valid-auc:0.796664
# [2]	train-auc:0.793945	valid-auc:0.7982
# [3]	train-auc:0.808859	valid-auc:0.806602
# [4]	train-auc:0.807372	valid-auc:0.806905
# [5]	train-auc:0.819533	valid-auc:0.821472
# [6]	train-auc:0.825141	valid-auc:0.828387
# [7]	train-auc:0.828222	valid-auc:0.828276
# [8]	train-auc:0.827415	valid-auc:0.827934
# [9]	train-auc:0.827064	valid-auc:0.828279
# [10]	train-auc:0.830463	valid-auc:0.835463
# [11]	train-auc:0.831571	valid-auc:0.834509
# [12]	train-auc:0.835062	valid-auc:0.838962
# [13]	train-auc:0.837909	valid-auc:0.842991
# [14]	train-auc:0.83857	valid-auc:0.844165
# [15]	train-auc:0.838603	valid-auc:0.844507
# [16]	train-auc:0.83846	valid-auc:0.844605
# [17]	train-auc:0.844205	valid-auc:0.849979
# [18]	train-auc:0.844244	valid-auc:0.851962
# [19]	train-auc:0.846942	valid-auc:0.854147
# [20]	train-auc:0.846321	valid-auc:0.853934
# [21]	train-auc:0.848338	valid-auc:0.856003
# [22]	train-auc:0.850775	valid-auc:0.856836
# [23]	train-auc:0.851327	valid-auc:0.856235
# [24]	train-auc:0.852245	valid-auc:0.856413
# [25]	train-auc:0.851975	valid-auc:0.855635
# [26]	train-auc:0.852824	valid-auc:0.856735
# [27]	train-auc:0.854702	valid-auc:0.858299
# [28]	train-auc:0.856925	valid-auc:0.859716
# [29]	train-auc:0.857284	valid-auc:0.861294
# [30]	train-auc:0.857653	valid-auc:0.861674
# [31]	train-auc:0.858088	valid-auc:0.862882
# [32]	train-auc:0.858075	valid-auc:0.863787
# [33]	train-auc:0.859374	valid-auc:0.863134
# [34]	train-auc:0.860604	valid-auc:0.863567
# [35]	train-auc:0.860703	valid-auc:0.863321
# [36]	train-auc:0.861539	valid-auc:0.862916
# [37]	train-auc:0.862594	valid-auc:0.86381
# [38]	train-auc:0.863772	valid-auc:0.864483
# [39]	train-auc:0.864334	valid-auc:0.864988
# [40]	train-auc:0.864778	valid-auc:0.864571
# [41]	train-auc:0.864755	valid-auc:0.864363
# [42]	train-auc:0.865486	valid-auc:0.863127
# [43]	train-auc:0.866137	valid-auc:0.863581
# [44]	train-auc:0.86674	valid-auc:0.862921
# [45]	train-auc:0.867229	valid-auc:0.865048
# [46]	train-auc:0.867452	valid-auc:0.866001
# [47]	train-auc:0.867757	valid-auc:0.866983
# [48]	train-auc:0.868714	valid-auc:0.86773
# [49]	train-auc:0.869017	valid-auc:0.868038
# [50]	train-auc:0.869637	valid-auc:0.86789
# [51]	train-auc:0.870011	valid-auc:0.86783
# [52]	train-auc:0.870346	valid-auc:0.867596
# [53]	train-auc:0.870181	valid-auc:0.868006
# [54]	train-auc:0.870118	valid-auc:0.867987
# [55]	train-auc:0.870362	valid-auc:0.867909
# [56]	train-auc:0.870757	valid-auc:0.868788
# [57]	train-auc:0.87101	valid-auc:0.868996
# [58]	train-auc:0.871279	valid-auc:0.869003
# [59]	train-auc:0.87161	valid-auc:0.869033
# [60]	train-auc:0.871717	valid-auc:0.868635
# [61]	train-auc:0.871819	valid-auc:0.868237
# [62]	train-auc:0.871832	valid-auc:0.868485
# [63]	train-auc:0.87225	valid-auc:0.868527
# [64]	train-auc:0.872375	valid-auc:0.868311
# [65]	train-auc:0.872571	valid-auc:0.867865
# [66]	train-auc:0.872918	valid-auc:0.868311
# [67]	train-auc:0.873237	valid-auc:0.868876
# [68]	train-auc:0.873363	valid-auc:0.869061
# [69]	train-auc:0.873536	valid-auc:0.869367
# [70]	train-auc:0.873779	valid-auc:0.869628
# [71]	train-auc:0.873894	valid-auc:0.868647
# [72]	train-auc:0.874217	valid-auc:0.86848
# [73]	train-auc:0.874571	valid-auc:0.869554
# [74]	train-auc:0.874673	valid-auc:0.869161
# [75]	train-auc:0.874845	valid-auc:0.869839
# [76]	train-auc:0.874962	valid-auc:0.870128
# [77]	train-auc:0.874882	valid-auc:0.870309
# [78]	train-auc:0.875202	valid-auc:0.870119
# [79]	train-auc:0.875357	valid-auc:0.870341
# [80]	train-auc:0.875464	valid-auc:0.870857
# [81]	train-auc:0.875622	valid-auc:0.871061
# [82]	train-auc:0.8758	valid-auc:0.870663
# [83]	train-auc:0.875967	valid-auc:0.870598
# [84]	train-auc:0.876041	valid-auc:0.870068
# [85]	train-auc:0.876261	valid-auc:0.870214
# [86]	train-auc:0.876427	valid-auc:0.870343
# [87]	train-auc:0.876595	valid-auc:0.870385
# [88]	train-auc:0.876735	valid-auc:0.870788
# [89]	train-auc:0.876888	valid-auc:0.87086
# [90]	train-auc:0.877093	valid-auc:0.870758
# [91]	train-auc:0.877229	valid-auc:0.87079
# [92]	train-auc:0.877333	valid-auc:0.870947
# [93]	train-auc:0.877507	valid-auc:0.870503
# [94]	train-auc:0.877587	valid-auc:0.870073
# [95]	train-auc:0.87781	valid-auc:0.869489
# [96]	train-auc:0.877931	valid-auc:0.86955
# [97]	train-auc:0.878059	valid-auc:0.869459
# [98]	train-auc:0.878136	valid-auc:0.869552
# [99]	train-auc:0.878054	valid-auc:0.869862
# [100]	train-auc:0.878212	valid-auc:0.869885
# [101]	train-auc:0.878235	valid-auc:0.870026
# Stopping. Best iteration:
# [81]	train-auc:0.875622	valid-auc:0.871061

# %% [markdown]
# ### Evaluate final model

# %%
print('     Train gini:',gini(data[train_mask][col_target], fxgb_scored[train_mask]))
print('Validation gini:',gini(data[valid_mask][col_target], fxgb_scored[valid_mask]))
# Out:
#      Train gini: 0.751244559662966
# Validation gini: 0.7421216834231332

# %% [markdown]
# #### Gain Importance

# %%
fs = fbooster.get_score(importance_type = 'gain') # available importance types: 'gain', 'cover', 'weight'
imp = sorted([(k, v) for k, v in fs.items()], key = lambda x:x[1], reverse = True)
imp.reverse()

fig = plt.figure(figsize=(12,9))
ax = fig.add_subplot(111)
ax.barh(range(len(imp)), [v for k, v in imp], color="blue",  align='center')
plt.yticks(range(len(imp)), [k for k, v in imp], fontsize=15)
plt.xticks(fontsize=15)
plt.xlabel('Importance',fontsize=15)
plt.ylim([-1, len(imp)])
plt.xlim([0, max([v for k, v in imp])*1.2])
plt.show()

# %% [markdown]
# Gain importance tells us the predictor relative contribution on each of the tree in the model. As you can see the **total_usage_per_limit**, **total_retail_usage**, and **delinquency_score** are the highest contributor to the model
#
# Furthermore, if we want to see the more specific explanation of these predictors SHAP module could be used

# %% [markdown]
# # Score the dataset

# %% [markdown]
# Create a new column with the prediction (probability of default).

# %%
col_score = 'LR_SCORE'
col_score1 = 'XGB_SCORE'

data[col_score] = lr_scored
print('Column',col_score,'with the prediction added/modified. Number of columns:',data.shape[1])

data[col_score1] = fxgb_scored
print('Column',col_score1,'with the prediction added/modified. Number of columns:',data.shape[1])
# Out:
# Column LR_SCORE with the prediction added/modified. Number of columns: 51
# Column XGB_SCORE with the prediction added/modified. Number of columns: 52

# %% [markdown]
# # Performance characteristics
# Performance characteristics of the models (Gini, Lift, KS) and their visualisations.

# %%
from ia_pkg.metrics import gini, lift, kolmogorov_smirnov
lift_perc = 10

# %% [markdown]
# ## Performance per sample

# %%
perf = pd.DataFrame({'sample':[
    'train',
    'valid',
    'test'    
    ], 'LR_gini':[
    gini(data[train_mask][col_target],data[train_mask][col_score]) #train
    ,gini(data[valid_mask][col_target],data[valid_mask][col_score]) #valid
    ,gini(data[test_mask][col_target],data[test_mask][col_score]) #test
    ], 'XGB_gini':[
    gini(data[train_mask][col_target],data[train_mask][col_score1]) #train
    ,gini(data[valid_mask][col_target],data[valid_mask][col_score1]) #valid
    ,gini(data[test_mask][col_target],data[test_mask][col_score1]) #test
    ], 'LR_lift'+str(lift_perc):[
    lift(data[train_mask][col_target],-data[train_mask][col_score],lift_perc) #train
    ,lift(data[valid_mask][col_target],-data[valid_mask][col_score],lift_perc) #valid
    ,lift(data[test_mask][col_target],-data[test_mask][col_score],lift_perc) #test
    ], 'XGB_lift'+str(lift_perc):[
    lift(data[train_mask][col_target],-data[train_mask][col_score1],lift_perc) #train
    ,lift(data[valid_mask][col_target],-data[valid_mask][col_score1],lift_perc) #valid
    ,lift(data[test_mask][col_target],-data[test_mask][col_score1],lift_perc) #test
    ], 'LR_KS':[
    kolmogorov_smirnov(data[train_mask][col_score],data[train_mask][col_target]) #train
    ,kolmogorov_smirnov(data[valid_mask][col_score],data[valid_mask][col_target]) #valid
    ,kolmogorov_smirnov(data[test_mask][col_score],data[test_mask][col_target]) #test
    ], 'XGB_KS':[
    kolmogorov_smirnov(data[train_mask][col_score1],data[train_mask][col_target]) #train
    ,kolmogorov_smirnov(data[valid_mask][col_score1],data[valid_mask][col_target]) #valid
    ,kolmogorov_smirnov(data[test_mask][col_score1],data[test_mask][col_target]) #test
    ]}).set_index('sample')

# %%
display(perf)
# Out:
#         LR_gini  XGB_gini  LR_lift10  XGB_lift10     LR_KS    XGB_KS
# sample
# train   0.49498  0.751245   3.424419    4.860177  0.348503  0.589378
# valid   0.56884  0.742122   4.039382    4.756047  0.428604  0.610579
# test    0.50732  0.712476   3.437517    4.419664  0.370417  0.576395

# %% [markdown]
# There is a huge difference on overall performance generated by these models. Could be data leakage issue on XGB model since the performance on valid and test is too high, need further investigation to prove it.

# %% [markdown]
# ## ROC Curve

# %%
from sklearn.metrics import roc_curve

# Compute ROC curve for each models
fpr = dict()
fpr = dict()
fpr1 = dict()    
tpr1 = dict()

fpr, tpr, _ = roc_curve(data[test_mask][col_target], data[test_mask][col_score])
fpr1, tpr1, _ = roc_curve(data[test_mask][col_target], data[test_mask][col_score1])

#Plot of a ROC curve
f, ax1 = plt.subplots(figsize=(6,6))
lw = 2
ax1.plot(fpr, tpr, color='y',label='LR ROC curve')
ax1.plot([0, 1], [0, 1], color='b', lw=lw, linestyle='--') 

ax2 = ax1.twinx()
ax2.plot(fpr1, tpr1, color='r',label='XGB ROC curve')
ax1.set_xlim([0.0, 1.0])
ax1.set_ylim([0.0, 1.0])
ax1.set_xlabel('False Positive Rate')
ax1.set_ylabel('True Positive Rate')
ax1.set_title('Receiver operating characteristic')
ax1.legend(bbox_to_anchor=(1, 0.1), borderaxespad=0.1)
ax2.legend(bbox_to_anchor=(1, 0.05), borderaxespad=0.1)
plt.show()

# %% [markdown]
# ## Score Linearity on Holdout Sample

# %%
from ia_pkg.plots import plot_score_linearity
plot_score_linearity(data[test_mask],
                    col_score=col_score1,
                    col_target=col_target,
                    bins=10)

# %%
plot_score_linearity(data[test_mask],
                    col_score=col_score,
                    col_target=col_target,
                    bins=10)

# %% [markdown]
# Score distribution is plotted in decile to show the linearity of the output score when we link it to their actual default rate.
#
# As you can see XGB could produce more consistent monotonicity than LR model, the reason is higher gini on XGB model
#
# Also when we see the PD score on x-axis for both models, it seems the spread tends to gathered at lower PD value, so default threshold 0.5 for cutoff would not be relevant in this case

# %% [markdown]
# ## Cut-Off Estimation

# %%
from ia_pkg.function import cutoff_df
from ia_pkg.plots import cutoff_plot

# Initialized all variable (expected default rate and scores)
exp_def_rate =0.025 # setting up the 2.5% expected default rate
scores = [col_score, col_score1]

# plot cutoff score
fig, ax = plt.subplots(figsize=(8,5))
for s in scores:
    dt = cutoff_df(data[valid_mask|test_mask],
                   col_score=s,
                   col_target=col_target)
    cutoff_plot(dt,
                col_score=s,
                exp_def_rate=exp_def_rate,
                ax=ax)

plt.title('Cumulative Distribution - PD Score vs Expected Default Rate')
plt.xlabel('PD Score')
plt.ylabel('Cummulative default rate')
plt.show()
# Out:
# The LR_SCORE cutoff to 2.50% default rate estimation: 0.014820313514992852
# The XGB_SCORE cutoff to 2.50% default rate estimation: 0.017703233286738396

# %% [markdown]
# Answering the problem task, the cutoff score is estimated by plotting the cumulative distribution of default rate to sorted score.
#
# Two models presented to see the optimal cutoff to manage below 2.5% default rate on the portfolio
#
# From the graph, we can decide for each cutoff score
#
# **LR model cutoff score : 0.01482**
#
# **XGB model cutoff score : 0.0177**

# %% [markdown]
# # Conclusion

# %% [markdown]
# - Credit score is created to predict the probability of default on provided dataset
#
#
# - Transformation and selection procedures is done to find the most useful predictors to the target
#
#
# - Two models(LR and XGB) with different methods are presented to be compared. From the evaluation, XGB has better performance than LR
#
#
# - The *deliquency_score* and *total_usage_per_limit* predictors considered as the highest contributor on both models
#
#
# - Decision for the choosed model not yet to be made since we need further investigation of too high performance and interpretability on one of the model (XGB model)
#
#
# - Optimal cutoff for 2.5% default rate : LR model is 0.01482 and XGB model is 0.0177
